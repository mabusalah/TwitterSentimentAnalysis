# %%
import pandas as pd, textblob, string
pd.set_option('display.max_colwidth', -1) #To show the whole tweet field
import numpy as np
import random
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics,svm
import seaborn as pl

# %%
#Import Training and Testing Data
train = pd.read_csv('train.csv')
print("Training Set:"% train.columns, train.shape, len(train))
test = pd.read_csv('test_tweets.csv')
print("Test Set:"% test.columns, test.shape, len(test))
#Percentage of Positive/Negative
print("Positive: ", train.label.value_counts()[0]/len(train_cl)*100,"%")
print("Negative: ", train.label.value_counts()[1]/len(train_cl)*100,"%")
# Out:
# Training Set: (31962, 3) 31962
# Test Set: (17197, 2) 17197
# Positive:  83.45735868130633 %
# Negative:  6.295807475218332 %

# %%
pl.countplot(train["label"])

# %%
#Remove Special Charactors
import re
from nltk.tokenize import WordPunctTokenizer
from bs4 import BeautifulSoup
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9/]+'
combined_pat = r'|'.join((pat1, pat2))

def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)    
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(letters_only)    
    sentence=[]
    for word in words:
        sentence.append(word)
        sentence.append(" ")
    words="".join(sentence).strip()    
    return words

# %%
nums = [0,len(train)]
clean_tweet_texts = []
for i in range(nums[0],nums[1]):
    clean_tweet_texts.append(tweet_cleaner(train['tweet'][i]))
nums = [0,len(test)]
test_tweet_texts = []
for i in range(nums[0],nums[1]):
    test_tweet_texts.append(tweet_cleaner(test['tweet'][i]))

train_clean = pd.DataFrame(clean_tweet_texts,columns=['tweet'])
train_clean['label'] = train.label
train_clean['id'] = train.id
test_clean = pd.DataFrame(test_tweet_texts,columns=['tweet'])
test_clean['id'] = test.id

# %%
train_clean[train_clean['label']==1].head()
# Out:
#                                                                                                tweet  \
# 13  cnn calls michigan middle school build the wall chant tcot
# 14  no comment in australia opkillingbay seashepherd helpcovedolphins thecove helpcovedolphins
# 17  retweet if you agree
# 23  lumpy says i am a prove it lumpy
# 34  it s unbelievable that in the st century we d need something like this again neverump xenophobia
#
#     label  id
# 13  1      14
# 14  1      15
# 17  1      18
# 23  1      24
# 34  1      35

# %%
train[train['label']==1].head()
# Out:
#     id  label  \
# 13  14  1
# 14  15  1
# 17  18  1
# 23  24  1
# 34  35  1
#
#                                                                                                        tweet
# 13  @user #cnn calls #michigan middle school 'build the wall' chant '' #tcot
# 14  no comment!  in #australia   #opkillingbay #seashepherd #helpcovedolphins #thecove  #helpcovedolphins
# 17  retweet if you agree!
# 23  @user @user lumpy says i am a . prove it lumpy.
# 34  it's unbelievable that in the 21st century we'd need something like this. again. #neverump  #xenophobia

# %%
# These mappings can get fairly large -- they're stored globally to
# save copying time.
#Reference
# (tuple of words) -> {dict: word -> number of times the word appears following the tuple}
# Example entry:
#    ('eyes', 'turned') => {'to': 2.0, 'from': 1.0}
# Used briefly while first constructing the normalized mapping
tempMapping = {}

# (tuple of words) -> {dict: word -> *normalized* number of times the word appears following the tuple}
# Example entry:
#    ('eyes', 'turned') => {'to': 0.66666666, 'from': 0.33333333}
mapping = {}

# Contains the set of words that can start sentences
starts = []

# We want to be able to compare words independent of their capitalization.
def fixCaps(word):
    # Ex: "FOO" -> "foo"
    if word.isupper() and word != "I":
        word = word.lower()
        # Ex: "LaTeX" => "Latex"
    elif word [0].isupper():
        word = word.lower().capitalize()
        # Ex: "wOOt" -> "woot"
    else:
        word = word.lower()
    return word

# Tuples can be hashed; lists can't.  We need hashable values for dict keys.
# This looks like a hack (and it is, a little) but in practice it doesn't
# affect processing time too negatively.
def toHashKey(lst):
    return tuple(lst)

# Returns the contents of the file, split into a list of words and
# (some) punctuation.
def wordlist(data):
    split_it = '. '.join([text for text in data])
    wordlist = [fixCaps(w) for w in re.findall(r"[\w']+|[.,!?;]", split_it)]    
    return wordlist

# Self-explanatory -- adds "word" to the "tempMapping" dict under "history".
# tempMapping (and mapping) both match each word to a list of possible next
# words.
# Given history = ["the", "rain", "in"] and word = "Spain", we add "Spain" to
# the entries for ["the", "rain", "in"], ["rain", "in"], and ["in"].
def addItemToTempMapping(history, word):
    global tempMapping
    while len(history) > 0:
        first = toHashKey(history)
        if first in tempMapping:
            if word in tempMapping[first]:
                tempMapping[first][word] += 1.0
            else:
                tempMapping[first][word] = 1.0
        else:
            tempMapping[first] = {}
            tempMapping[first][word] = 1.0
        history = history[1:]

# Building and normalizing the mapping.
def buildMapping(wordlist, markovLength):
    global tempMapping
    starts.append(wordlist [0])
    for i in range(1, len(wordlist) - 1):
        if i <= markovLength:
            history = wordlist[: i + 1]
        else:
            history = wordlist[i - markovLength + 1 : i + 1]
        follow = wordlist[i + 1]
        # if the last elt was a period, add the next word to the start list
        if history[-1] == "." and follow not in ".,!?;":
            starts.append(follow)
        addItemToTempMapping(history, follow)
    # Normalize the values in tempMapping, put them into mapping
    for first, followset in tempMapping.items():
        total = sum(followset.values())
        # Normalizing here:
        mapping[first] = dict([(k, v / total) for k, v in followset.items()])

# Returns the next word in the sentence (chosen randomly),
# given the previous ones.
def next(prevList):
    sum = 0.0
    retval = ""
    index = random.random()
    # Shorten prevList until it's in mapping
    while toHashKey(prevList) not in mapping:
        try:
            prevList.pop(0)
        except:
            prevList=random.choice(starts)
    # Get a random word from the mapping, given prevList
    for k, v in mapping[toHashKey(prevList)].items():
        sum += v
        if sum >= index and retval == "":
            retval = k
    return retval

def genSentence(markovLength):
    # Start with a random "starting word"
    curr = random.choice(starts)
    sent = curr.capitalize()
    prevList = [curr]
    # Keep adding words until we hit a period
    while (curr not in "."):
        curr = next(prevList)
        prevList.append(curr)        
        # if the prevList has gotten too long, trim it
        if len(prevList) > markovLength:
            prevList.pop(0)
        if (curr not in ".,!?;"):
            sent += " " # Add spaces between words (but not punctuation)
        sent += curr
    return sent

# %%
tempMapping
# Out:
# {('cnn', 'calls'): {'michigan': 2.0},
#  ('calls',): {'michigan': 2.0,
#   'me': 1.0,
#   'her': 1.0,
#   'for': 5.0,
#   'an': 1.0,
#   'americans': 2.0},
#  ('cnn', 'calls', 'michigan'): {'middle': 1.0},
#  ('calls', 'michigan'): {'middle': 2.0},
#  ('michigan',): {'middle': 2.0},
#  ('michigan', 'middle'): {'school': 2.0},
#  ('middle',): {'school': 2.0},
#  ('middle', 'school'): {'build': 2.0},
#  ('school',): {'build': 2.0,
#   'districts': 2.0,
#   'board': 8.0,
#   'i': 1.0,
#   'game': 1.0,
#   'texas': 1.0,
#   'and': 1.0,
#   'district': 1.0},
#  ('school', 'build'): {'the': 2.0},
#  ('build',): {'the': 2.0, 'our': 1.0, 'bridges': 1.0, 'walls': 1.0},
#  ('build', 'the'): {'wall': 2.0},
#  ('the',): {'wall': 4.0,
#   'st': 3.0,
#   'white': 16.0,
#   'altright': 3.0,
#   'smaller': 1.0,
#   'trash': 1.0,
#   'state': 1.0,
#   'biggest': 2.0,
#   'same': 13.0,
#   'dying': 2.0,
#   'light': 3.0,
#   'nazi': 3.0,
#   'pic': 1.0,
#   'nazis': 2.0,
#   'consequences': 1.0,
#   'are': 51.0,
#   'more': 6.0,
#   'asians': 1.0,
#   'africans': 1.0,
#   'police': 3.0,
#   'world': 18.0,
#   'blacklivesmatter': 1.0,
#   'most': 12.0,
#   'latest': 28.0,
#   'company': 1.0,
#   's': 3.0,
#   'danger': 1.0,
#   'money': 1.0,
#   'power': 3.0,
#   'vile': 1.0,
#   'criminal': 1.0,
#   'opposition': 2.0,
#   'advancement': 1.0,
#   'will': 1.0,
#   'small': 1.0,
#   'jews': 2.0,
#   'next': 5.0,
#   'volatile': 1.0,
#   'free': 1.0,
#   'plane': 1.0,
#   'fn': 1.0,
#   '.': 8.0,
#   'incessant': 2.0,
#   'maryland': 1.0,
#   'worst': 5.0,
#   'curriculum': 1.0,
#   'only': 5.0,
#   'process': 1.0,
#   'democraticpay': 4.0,
#   'rest': 7.0,
#   'age': 2.0,
#   'true': 2.0,
#   'magical': 1.0,
#   'problem': 4.0,
#   'show': 1.0,
#   'pay': 4.0,
#   'blunt': 2.0,
#   'first': 3.0,
#   'popularvote': 2.0,
#   'deadliest': 3.0,
#   'electoralcollege': 1.0,
#   'dumb': 1.0,
#   'lgbtq': 1.0,
#   'arabs': 1.0,
#   'poor': 3.0,
#   'face': 5.0,
#   'cnn': 1.0,
#   'heck': 1.0,
#   'crusader': 2.0,
#   'daily': 3.0,
#   'sad': 2.0,
#   'mil': 7.0,
#   'revolution': 2.0,
#   'dictionary': 1.0,
#   'education': 1.0,
#   'path': 1.0,
#   'truth': 5.0,
#   'holidays': 2.0,
#   'correct': 1.0,
#   'numbers': 1.0,
#   'right': 3.0,
#   'principal': 1.0,
#   'politicians': 1.0,
#   'judges': 1.0,
#   'snowball': 2.0,
#   'impoance': 2.0,
#   'clock': 1.0,
#   'idea': 1.0,
#   'market': 4.0,
#   'burka': 1.0,
#   'implication': 1.0,
#   'hate': 2.0,
#   'gop': 1.0,
#   'last': 1.0,
#   'swamp': 1.0,
#   'guns': 1.0,
#   'word': 9.0,
#   'lady': 1.0,
#   'juniors': 1.0,
#   'fear': 1.0,
#   'loudest': 1.0,
#   'kitchen': 1.0,
#   'coal': 1.0,
#   'trump': 5.0,
#   'sisterinlaw': 1.0,
#   'way': 5.0,
#   'eyes': 2.0,
#   'libtard': 2.0,
#   'perks': 1.0,
#   'point': 3.0,
#   'african': 2.0,
#   'alt': 7.0,
#   'dictator': 2.0,
#   'keys': 1.0,
#   'usa': 9.0,
#   'people': 7.0,
#   'bear': 4.0,
#   'patience': 2.0,
#   'stupidity': 1.0,
#   'alcoholic': 1.0,
#   'stuff': 1.0,
#   'english': 1.0,
#   'hell': 1.0,
#   'healand': 1.0,
#   'day': 3.0,
#   'government': 2.0,
#   'deplorables': 2.0,
#   'that': 1.0,
#   'lgbti': 1.0,
#   'impression': 6.0,
#   'fully': 1.0,
#   'year': 3.0,
#   'game': 2.0,
#   'workplace': 3.0,
#   'reaction': 1.0,
#   'balls': 4.0,
#   'mayor': 1.0,
#   'city': 2.0,
#   'knitting': 1.0,
#   'odd': 1.0,
#   'well': 1.0,
#   'fact': 1.0,
#   'brown': 1.0,
#   'bills': 1.0,
#   'master': 1.0,
#   'inexistence': 1.0,
#   'countdown': 1.0,
#   'local': 1.0,
#   'cold': 4.0,
#   'repug': 1.0,
#   'bigot': 1.0,
#   'waiter': 2.0,
#   'plate': 1.0,
#   'left': 3.0,
#   'music': 4.0,
#   'anc': 3.0,
#   'da': 2.0,
#   'systemic': 2.0,
#   'work': 1.0,
#   'lead': 1.0,
#   'uneducated': 1.0,
#   'deafening': 1.0,
#   'gate': 1.0,
#   'juice': 1.0,
#   'huffington': 1.0,
#   'fang': 7.0,
#   'net': 1.0,
#   'liveleap': 1.0,
#   'scars': 1.0,
#   'league': 1.0,
#   'answer': 1.0,
#   'job': 6.0,
#   'bbc': 2.0,
#   'jackals': 2.0,
#   'blog': 1.0,
#   'debate': 1.0,
#   'one': 2.0,
#   'obamas': 5.0,
#   'odds': 1.0,
#   'gangs': 1.0,
#   'blicqer': 6.0,
#   'all': 1.0,
#   'inauguration': 3.0,
#   'stomping': 1.0,
#   'facts': 1.0,
#   'snowpeople': 1.0,
#   'soul': 1.0,
#   'fugly': 1.0,
#   'c': 1.0,
#   'fuck': 2.0,
#   'media': 3.0,
#   'threat': 1.0,
#   'best': 3.0,
#   'historian': 1.0,
#   'bodies': 1.0,
#   'sites': 1.0,
#   'idiocy': 1.0,
#   'proof': 1.0,
#   'champ': 1.0,
#   'religion': 1.0,
#   'wilfully': 2.0,
#   'mogage': 1.0,
#   'argument': 1.0,
#   'news': 1.0,
#   'political': 3.0,
#   'terms': 1.0,
#   'brexit': 1.0,
#   'fascist': 1.0,
#   'neck': 1.0,
#   'th': 4.0,
#   'equality': 1.0,
#   'united': 2.0,
#   'better': 1.0,
#   'neighbor': 1.0,
#   'cop': 1.0,
#   'kid': 1.0,
#   'assault': 1.0,
#   'ki': 1.0,
#   'adhan': 1.0,
#   'kaaba': 1.0,
#   'temptation': 1.0,
#   'cowboys': 1.0,
#   'sitting': 1.0,
#   'he': 1.0,
#   'us': 6.0,
#   'genocide': 1.0,
#   'lds': 2.0,
#   'emoji': 1.0,
#   'indigenous': 1.0,
#   'majority': 2.0,
#   'ironies': 1.0,
#   'old': 1.0,
#   'eah': 1.0,
#   'past': 2.0,
#   'public': 1.0,
#   'block': 1.0,
#   'course': 1.0,
#   'festive': 1.0,
#   'end': 3.0,
#   'afl': 1.0,
#   'mannequinchallenge': 1.0,
#   'hereticfoundation': 2.0,
#   'unforgettable': 1.0,
#   'heabroken': 1.0,
#   'use': 1.0,
#   'producers': 1.0,
#   'unitednations': 1.0,
#   'pre': 2.0,
#   'want': 1.0,
#   'extremists': 2.0,
#   'root': 1.0,
#   'rape': 3.0,
#   'summer': 1.0,
#   'wild': 1.0,
#   'knee': 1.0,
#   'murrayhaters': 1.0,
#   'reason': 1.0,
#   'future': 1.0,
#   'raison': 1.0,
#   'adl': 1.0,
#   'for': 4.0,
#   'lack': 1.0,
#   'millions': 2.0,
#   'women': 3.0,
#   'teapay': 2.0,
#   'airpo': 1.0,
#   'door': 1.0,
#   'wilmington': 1.0,
#   'guys': 1.0,
#   'title': 1.0,
#   'season': 1.0,
#   'lgbt': 2.0,
#   'term': 4.0,
#   'march': 1.0,
#   'to': 1.0,
#   'church': 1.0,
#   'biopolitics': 1.0,
#   'reemergence': 1.0,
#   'disgusting': 1.0,
#   'chaer': 1.0,
#   'flag': 2.0,
#   'italian': 1.0,
#   'saudi': 1.0,
#   'token': 1.0,
#   'action': 1.0,
#   'freemasons': 1.0,
#   'phone': 1.0,
#   'thug': 1.0,
#   'common': 1.0,
#   'school': 1.0,
#   'sales': 1.0,
#   'words': 1.0,
#   'king': 1.0,
#   'queen': 1.0,
#   'bugg': 1.0,
#   'sta': 1.0,
#   'zurich': 1.0,
#   'bus': 1.0,
#   'difference': 1.0,
#   'oven': 1.0,
#   'oppressor': 1.0,
#   'life': 1.0,
#   'uk': 6.0,
#   'eu': 1.0,
#   'battle': 1.0,
#   'new': 2.0,
#   'men': 1.0,
#   'driver': 1.0,
#   'main': 1.0,
#   'accusations': 1.0,
#   'kind': 3.0,
#   'ground': 1.0,
#   'fight': 1.0,
#   'wrongful': 1.0,
#   'parent': 1.0,
#   'date': 2.0,
#   'racist': 3.0,
#   'type': 1.0,
#   'space': 1.0,
#   'hateful': 1.0,
#   'cognizant': 1.0,
#   'kkk': 4.0,
#   'immature': 1.0,
#   'ear': 1.0,
#   'case': 1.0,
#   'commonwealth': 1.0,
#   'internet': 1.0,
#   'evidence': 1.0,
#   'pros': 1.0,
#   'reality': 2.0,
#   'tech': 2.0,
#   'ellicottsquarebuilding': 1.0,
#   'nc': 1.0,
#   'major': 2.0,
#   'flight': 1.0,
#   'real': 6.0,
#   'pigs': 1.0,
#   'innocent': 1.0,
#   'progressive': 2.0,
#   'seattle': 1.0,
#   'helm': 1.0,
#   'feeling': 1.0,
#   'chinese': 1.0,
#   'southern': 2.0,
#   'human': 1.0,
#   'you': 1.0,
#   'guy': 1.0,
#   'pc': 1.0,
#   'trumphate': 1.0,
#   'risk': 1.0,
#   'and': 1.0,
#   'holiday': 1.0,
#   'rules': 1.0,
#   'radicalism': 1.0,
#   'roots': 1.0,
#   'home': 1.0,
#   'supremecou': 1.0,
#   'globe': 1.0,
#   'decision': 1.0,
#   'car': 1.0,
#   'time': 2.0,
#   'deep': 1.0,
#   'merocrush': 1.0,
#   'idiot': 1.0,
#   'trumpdarkzone': 1.0,
#   'matter': 1.0,
#   'hc': 1.0,
#   'everyday': 1.0,
#   'beginning': 2.0,
#   'apaheid': 1.0,
#   'south': 1.0,
#   'american': 1.0,
#   'shackles': 2.0,
#   'messiah': 1.0,
#   'plight': 1.0,
#   'palestinians': 1.0,
#   'largest': 2.0,
#   'families': 1.0,
#   'd': 1.0,
#   'glitter': 1.0,
#   'confederateflag': 1.0,
#   'discrepancy': 1.0,
#   'great': 1.0,
#   'story': 1.0,
#   'blacks': 4.0,
#   'legacy': 1.0,
#   'boot': 1.0,
#   'homophobe': 1.0,
#   'above': 1.0,
#   'masses': 1.0,
#   'inter': 1.0,
#   'pap': 1.0,
#   'window': 1.0,
#   'mummersparade': 3.0,
#   'civil': 1.0,
#   'japanese': 1.0,
#   'pizza': 1.0,
#   'piss': 1.0,
#   'eff': 2.0,
#   'open': 1.0,
#   'child': 1.0,
#   'tinyfingeredpuppet': 1.0,
#   'black': 1.0,
#   'spirit': 1.0,
#   'nose': 1.0,
#   'n': 1.0,
#   'equivalent': 1.0,
#   'press': 1.0,
#   'nikita': 1.0,
#   'second': 1.0,
#   'effect': 1.0,
#   'bin': 1.0,
#   'bitch': 1.0,
#   'democratic': 1.0,
#   'look': 1.0,
#   'tornado': 1.0,
#   'neighborhood': 1.0,
#   'ssn': 1.0,
#   'ignorant': 1.0,
#   'scumbag': 1.0,
#   'terrorists': 1.0,
#   'crack': 1.0,
#   'diversity': 1.0,
#   'number': 1.0,
#   'idiotic': 1.0,
#   'bad': 1.0,
#   'corruption': 1.0,
#   'rockette': 1.0,
#   'horizon': 1.0,
#   'so': 1.0,
#   'incineration': 1.0,
#   'dems': 1.0,
#   'whole': 1.0,
#   'street': 1.0,
#   'gutter': 1.0,
#   'gentlemen': 1.0},
#  ('the', 'wall'): {'chant': 2.0, 'street': 2.0},
#  ('wall',): {'chant': 2.0,
#   'is': 1.0,
#   'street': 4.0,
#   'to': 1.0,
#   'coverage': 1.0},
#  ('wall', 'chant'): {'tcot': 2.0},
#  ('chant',): {'tcot': 2.0, 'free': 1.0},
#  ('chant', 'tcot'): {'.': 2.0},
#  ('tcot',): {'.': 5.0,
#   'tpc': 2.0,
#   'p': 1.0,
#   'tlot': 2.0,
#   'feminism': 1.0,
#   'gets': 1.0,
#   'blacktwitter': 1.0,
#   'maga': 1.0},
#  ('tcot', '.'): {'no': 1.0,
#   'the': 1.0,
#   'save': 1.0,
#   'dearfellowwhitepeople': 1.0,
#   'agreed': 1.0},
#  ('.',): {'no': 26.0,
#   'retweet': 2.0,
#   'lumpy': 1.0,
#   'it': 23.0,
#   'lets': 1.0,
#   'the': 99.0,
#   'hey': 8.0,
#   'how': 26.0,
#   'i': 80.0,
#   'why': 34.0,
#   'people': 15.0,
#   'yes': 4.0,
#   'as': 4.0,
#   'you': 114.0,
#   'take': 1.0,
#   'if': 32.0,
#   'this': 50.0,
#   'stereotyping': 1.0,
#   'horribly': 1.0,
#   'trump': 32.0,
#   'when': 10.0,
#   'biherism': 1.0,
#   'fo': 3.0,
#   'discussing': 1.0,
#   'are': 57.0,
#   'allahsoil': 89.0,
#   'anti': 3.0,
#   'that': 10.0,
#   'girls': 4.0,
#   'feminismiscancer': 20.0,
#   'fox': 2.0,
#   'porn': 7.0,
#   'just': 15.0,
#   'nigger': 4.0,
#   'carolyn': 1.0,
#   'standing': 1.0,
#   'everytime': 2.0,
#   'great': 9.0,
#   'thank': 6.0,
#   'and': 24.0,
#   'any': 2.0,
#   'jan': 1.0,
#   'keep': 5.0,
#   'jake': 1.0,
#   'is': 30.0,
#   'rushlimbaugh': 1.0,
#   'black': 16.0,
#   'trumpusa': 4.0,
#   'msg': 2.0,
#   'non': 1.0,
#   'don': 10.0,
#   'who': 6.0,
#   'radicalism': 1.0,
#   'but': 3.0,
#   'todays': 3.0,
#   'all': 8.0,
#   'also': 2.0,
#   'although': 1.0,
#   'what': 23.0,
#   'decolonizing': 1.0,
#   'yay': 1.0,
#   'newyear': 4.0,
#   'because': 8.0,
#   'buffalo': 6.0,
#   'dear': 10.0,
#   'pay': 3.0,
#   'ultimately': 2.0,
#   'shot': 2.0,
#   'do': 3.0,
#   'tyler': 3.0,
#   'smh': 1.0,
#   'get': 2.0,
#   'psa': 2.0,
#   'sikh': 26.0,
#   'feds': 1.0,
#   'own': 7.0,
#   'paul': 3.0,
#   'lying': 1.0,
#   'bullshit': 2.0,
#   'hope': 2.0,
#   'hillaryclinton': 1.0,
#   'japan': 2.0,
#   'homegrown': 1.0,
#   'in': 20.0,
#   'malia': 2.0,
#   'gop': 2.0,
#   'names': 2.0,
#   'chick': 4.0,
#   'sex': 5.0,
#   'riyadh': 1.0,
#   'needs': 2.0,
#   'seriously': 4.0,
#   'for': 3.0,
#   'argentine': 1.0,
#   'show': 1.0,
#   'harbaugh': 1.0,
#   'techjunkiejh': 3.0,
#   'sea': 19.0,
#   'proves': 1.0,
#   'travelled': 2.0,
#   'check': 5.0,
#   'stocking': 1.0,
#   'most': 5.0,
#   'donkey': 2.0,
#   'trophy': 2.0,
#   'a': 23.0,
#   'fascism': 2.0,
#   'has': 3.0,
#   'happy': 5.0,
#   'only': 5.0,
#   'multiple': 3.0,
#   'disgusting': 1.0,
#   'girl': 2.0,
#   'democrat': 1.0,
#   'aloha': 1.0,
#   'nyc': 1.0,
#   'texas': 2.0,
#   'beware': 3.0,
#   'chepstow': 1.0,
#   'christians': 2.0,
#   'dealing': 1.0,
#   'we': 16.0,
#   'work': 1.0,
#   'sad': 3.0,
#   'lessons': 1.0,
#   'hours': 2.0,
#   'carlpalladino': 1.0,
#   'new': 7.0,
#   'launching': 1.0,
#   'outrageous': 2.0,
#   'shut': 1.0,
#   'exemplifies': 1.0,
#   'alexpascal': 1.0,
#   'falsenarrative': 1.0,
#   'episode': 1.0,
#   'obama': 8.0,
#   'prison': 2.0,
#   'speaking': 1.0,
#   'icymi': 2.0,
#   'women': 1.0,
#   'your': 14.0,
#   'gtfoh': 1.0,
#   'police': 2.0,
#   'stop': 11.0,
#   'jeff': 3.0,
#   'nigelfarage': 1.0,
#   'wants': 1.0,
#   'trumps': 2.0,
#   'will': 12.0,
#   'mcconnell': 2.0,
#   'so': 21.0,
#   'diisgusted': 1.0,
#   'nicola': 1.0,
#   'india': 1.0,
#   'anyone': 3.0,
#   'word': 6.0,
#   'chaplin': 2.0,
#   'excellent': 4.0,
#   'again': 2.0,
#   'carl': 5.0,
#   'gives': 1.0,
#   'make': 1.0,
#   'piece': 1.0,
#   'video': 9.0,
#   'crybully': 1.0,
#   'here': 7.0,
#   'whitenationalist': 1.0,
#   'win': 1.0,
#   'was': 2.0,
#   'good': 4.0,
#   'precisely': 2.0,
#   'lgbti': 1.0,
#   'nothing': 10.0,
#   'luicalibre': 1.0,
#   'fuck': 5.0,
#   'researchers': 1.0,
#   'wen': 1.0,
#   'he': 8.0,
#   'feminism': 1.0,
#   'bout': 2.0,
#   'my': 9.0,
#   'her': 1.0,
#   'truth': 1.0,
#   'these': 3.0,
#   'says': 5.0,
#   'peruvian': 1.0,
#   'greek': 1.0,
#   'manipur': 1.0,
#   'ik': 1.0,
#   'kevin': 3.0,
#   'reading': 2.0,
#   'j': 1.0,
#   'peace': 1.0,
#   'have': 3.0,
#   'typical': 2.0,
#   'tragic': 1.0,
#   'suspected': 2.0,
#   'mean': 1.0,
#   'can': 6.0,
#   'everyday': 1.0,
#   'at': 1.0,
#   'thought': 14.0,
#   'evolution': 1.0,
#   'freaking': 1.0,
#   'indianapolis': 2.0,
#   'rupemurdoch': 1.0,
#   'from': 2.0,
#   'french': 1.0,
#   'holiday': 3.0,
#   'nazi': 1.0,
#   'please': 11.0,
#   'movie': 1.0,
#   'caturday': 1.0,
#   'thanks': 4.0,
#   'like': 2.0,
#   'man': 2.0,
#   'never': 1.0,
#   'bluelivesmatter': 1.0,
#   'damn': 1.0,
#   'cleveland': 2.0,
#   'mustread': 2.0,
#   'bigot': 1.0,
#   'tell': 2.0,
#   'wahhhh': 1.0,
#   'makes': 2.0,
#   'climatechange': 1.0,
#   'atk': 1.0,
#   'miami': 2.0,
#   'did': 6.0,
#   'while': 2.0,
#   'fantastic': 1.0,
#   'hatecrime': 1.0,
#   'patriotwatch': 3.0,
#   'ends': 4.0,
#   'two': 1.0,
#   'scatter': 1.0,
#   'deafed': 1.0,
#   'whining': 1.0,
#   'council': 2.0,
#   'emma': 1.0,
#   'clearly': 1.0,
#   'less': 1.0,
#   'nick': 2.0,
#   'newyearseve': 3.0,
#   'caroline': 1.0,
#   'congrats': 1.0,
#   'those': 3.0,
#   'jcpenny': 1.0,
#   'white': 12.0,
#   'tonight': 1.0,
#   'more': 6.0,
#   'ouuh': 1.0,
#   'pathetic': 1.0,
#   'michelleobama': 1.0,
#   'mizzou': 1.0,
#   'rohingya': 1.0,
#   'pastor': 1.0,
#   'racial': 4.0,
#   'lock': 1.0,
#   'engagement': 1.0,
#   'blacklivesmatter': 2.0,
#   'twitter': 1.0,
#   'critics': 1.0,
#   'president': 3.0,
#   'stuakenyon': 1.0,
#   'note': 2.0,
#   'yoyas': 1.0,
#   'preorder': 4.0,
#   'book': 5.0,
#   'come': 3.0,
#   'aptly': 1.0,
#   'ebonics': 1.0,
#   'libtard': 3.0,
#   'hello': 2.0,
#   'racism': 10.0,
#   'one': 2.0,
#   'carlpaladino': 5.0,
#   'racist': 6.0,
#   'kinda': 1.0,
#   'uk': 3.0,
#   'haha': 2.0,
#   'resign': 1.0,
#   'next': 2.0,
#   'economicsanctions': 1.0,
#   'classic': 1.0,
#   'directly': 1.0,
#   'huh': 1.0,
#   'donaldtrump': 2.0,
#   'goverment': 1.0,
#   'expressions': 1.0,
#   'university': 1.0,
#   'both': 1.0,
#   'kindledeals': 1.0,
#   'suck': 1.0,
#   'microsoft': 1.0,
#   'pos': 1.0,
#   'reject': 3.0,
#   'pure': 1.0,
#   'live': 1.0,
#   'intolerant': 2.0,
#   'expes': 1.0,
#   'sickening': 1.0,
#   'woman': 3.0,
#   'maga': 2.0,
#   'go': 3.0,
#   'st': 1.0,
#   'charles': 1.0,
#   'welcome': 2.0,
#   'confessions': 1.0,
#   'boob': 3.0,
#   'potus': 1.0,
#   'read': 1.0,
#   'now': 4.0,
#   'would': 2.0,
#   'b': 1.0,
#   'notmypresident': 1.0,
#   'goodes': 1.0,
#   'pt': 1.0,
#   'allows': 1.0,
#   'ufc': 1.0,
#   'oops': 3.0,
#   'someone': 2.0,
#   'boycotting': 1.0,
#   'classy': 1.0,
#   'motherhood': 1.0,
#   'proved': 1.0,
#   'total': 1.0,
#   'cept': 1.0,
#   'adveisments': 1.0,
#   'boycott': 1.0,
#   'scary': 1.0,
#   'insane': 1.0,
#   'cuomo': 2.0,
#   'carriefisher': 1.0,
#   'absolutely': 1.0,
#   'its': 2.0,
#   'worst': 1.0,
#   'leave': 3.0,
#   'our': 1.0,
#   'content': 2.0,
#   'drsuess': 1.0,
#   'barack': 1.0,
#   'plz': 3.0,
#   'megaupload': 1.0,
#   'easy': 1.0,
#   'nazis': 1.0,
#   'y': 1.0,
#   'surprise': 1.0,
#   'outraged': 1.0,
#   'hitler': 1.0,
#   'dull': 1.0,
#   'reagan': 1.0,
#   'im': 1.0,
#   'sick': 1.0,
#   'hamzayusuf': 1.0,
#   'many': 2.0,
#   'netanyahuspeech': 1.0,
#   'crazed': 1.0,
#   'presidents': 2.0,
#   'washington': 1.0,
#   'woh': 1.0,
#   'supermariorun': 1.0,
#   'sadly': 1.0,
#   'smoke': 1.0,
#   'small': 1.0,
#   'christmas': 1.0,
#   'waitingf': 2.0,
#   'bookreview': 1.0,
#   'green': 2.0,
#   'thats': 2.0,
#   'far': 1.0,
#   'empress': 1.0,
#   'ark': 1.0,
#   'alt': 2.0,
#   'not': 7.0,
#   'over': 3.0,
#   'free': 3.0,
#   're': 1.0,
#   'everything': 1.0,
#   'oh': 3.0,
#   'care': 1.0,
#   'stay': 1.0,
#   'beyond': 1.0,
#   'islam': 2.0,
#   'marco': 1.0,
#   'statement': 1.0,
#   'intrumpsamerica': 1.0,
#   'paladino': 2.0,
#   'rambling': 1.0,
#   'ain': 1.0,
#   'heard': 1.0,
#   'vs': 1.0,
#   'tory': 1.0,
#   'jonjo': 1.0,
#   'amateur': 1.0,
#   'ppl': 2.0,
#   'coming': 3.0,
#   'lame': 1.0,
#   'irritations': 1.0,
#   'anybody': 1.0,
#   'best': 1.0,
#   'al': 1.0,
#   'omg': 2.0,
#   'does': 1.0,
#   'sign': 1.0,
#   'theresistance': 3.0,
#   'incredible': 1.0,
#   'democrats': 1.0,
#   'emmastone': 1.0,
#   'almost': 1.0,
#   'fear': 1.0,
#   'israel': 2.0,
#   'release': 1.0,
#   'back': 1.0,
#   'male': 1.0,
#   'spoty': 1.0,
#   'seems': 3.0,
#   'whitegenocide': 1.0,
#   'becoming': 1.0,
#   'right': 1.0,
#   'fucking': 2.0,
#   'adl': 1.0,
#   'koreans': 4.0,
#   'explain': 2.0,
#   'some': 1.0,
#   'research': 1.0,
#   'adam': 1.0,
#   'realitycheck': 2.0,
#   'farmer': 1.0,
#   'treasonoustrump': 1.0,
#   'mediamisogyny': 1.0,
#   'montana': 1.0,
#   'tyruswong': 1.0,
#   'vandals': 2.0,
#   'share': 2.0,
#   'america': 3.0,
#   'meet': 2.0,
#   'commercial': 2.0,
#   'wew': 1.0,
#   'must': 2.0,
#   'melania': 1.0,
#   'tis': 1.0,
#   'everyone': 3.0,
#   'ha': 1.0,
#   'saw': 1.0,
#   'jeffsessions': 6.0,
#   'every': 1.0,
#   'millennials': 1.0,
#   'victim': 1.0,
#   'there': 5.0,
#   'azealia': 1.0,
#   'lmfao': 1.0,
#   'comment': 1.0,
#   'then': 1.0,
#   'instagram': 1.0,
#   'msnbc': 3.0,
#   'congressman': 1.0,
#   'kkk': 1.0,
#   'she': 2.0,
#   'tbt': 1.0,
#   'put': 1.0,
#   'ag': 2.0,
#   'nope': 1.0,
#   'remark': 1.0,
#   'snatch': 1.0,
#   'cutsie': 1.0,
#   'italians': 1.0,
#   'yup': 2.0,
#   'thoughts': 1.0,
#   'listen': 1.0,
#   'putin': 1.0,
#   'aleppo': 1.0,
#   'donald': 2.0,
#   'blacklivesmatters': 1.0,
#   'disgrace': 1.0,
#   'want': 1.0,
#   'wtf': 2.0,
#   'today': 2.0,
#   'wow': 4.0,
#   'mud': 1.0,
#   'freedownload': 1.0,
#   'virginia': 1.0,
#   'kicking': 1.0,
#   'priyankachopra': 2.0,
#   'racists': 1.0,
#   'joemixon': 1.0,
#   'hidden': 1.0,
#   'smileyong': 1.0,
#   'marijuana': 1.0,
#   'shocker': 1.0,
#   'axed': 1.0,
#   'auspol': 1.0,
#   'school': 1.0,
#   'australia': 1.0,
#   'rise': 2.0,
#   'intercourse': 1.0,
#   'republican': 1.0,
#   'salt': 1.0,
#   'bustyescos': 1.0,
#   'true': 1.0,
#   'arc': 1.0,
#   'ohhhh': 1.0,
#   'jessica': 1.0,
#   'terry': 1.0,
#   'pa': 1.0,
#   'based': 1.0,
#   'silveragatka': 1.0,
#   'sexy': 1.0,
#   'hot': 4.0,
#   'of': 2.0,
#   'spos': 1.0,
#   'quotes': 1.0,
#   'ifyousawinyouwhatisee': 1.0,
#   'mixed': 1.0,
#   'wish': 1.0,
#   'lanasprayberry': 1.0,
#   'cnn': 1.0,
#   'save': 2.0,
#   'prolapsed': 1.0,
#   'men': 1.0,
#   'review': 1.0,
#   'homicides': 2.0,
#   'ohio': 1.0,
#   'ed': 1.0,
#   'lolol': 1.0,
#   'u': 1.0,
#   'w': 1.0,
#   'jews': 2.0,
#   'sexist': 1.0,
#   'flashbackfriday': 1.0,
#   'after': 4.0,
#   'ouch': 2.0,
#   'could': 1.0,
#   'mtv': 1.0,
#   'nites': 1.0,
#   'delta': 1.0,
#   'ending': 1.0,
#   'awesome': 2.0,
#   'boys': 1.0,
#   'opinion': 1.0,
#   'us': 6.0,
#   'f': 2.0,
#   'remember': 1.0,
#   'crazy': 1.0,
#   'ya': 1.0,
#   'scrutinize': 2.0,
#   'alabama': 1.0,
#   'antiwhite': 1.0,
#   'fl': 1.0,
#   'silence': 1.0,
#   'preach': 1.0,
#   'grows': 1.0,
#   'scapelliti': 2.0,
#   'advanced': 3.0,
#   'charlespaladino': 1.0,
#   'ny': 1.0,
#   'cctv': 1.0,
#   'essential': 1.0,
#   'rebellion': 2.0,
#   'lee': 1.0,
#   'ever': 2.0,
#   'greed': 1.0,
#   'netanyahu': 1.0,
#   'where': 2.0,
#   'pm': 1.0,
#   'mma': 2.0,
#   'on': 2.0,
#   'anc': 2.0,
#   'bot': 2.0,
#   'listening': 1.0,
#   'lesson': 1.0,
#   'clickbait': 1.0,
#   'indeed': 1.0,
#   'relied': 1.0,
#   'apparently': 2.0,
#   'bjork': 1.0,
#   'joy': 1.0,
#   'fake': 1.0,
#   'well': 3.0,
#   'hmmm': 1.0,
#   'cpcldr': 1.0,
#   'cologne': 1.0,
#   'calls': 1.0,
#   'smiling': 1.0,
#   'josephjett': 2.0,
#   'done': 1.0,
#   'universityofwisconsinmadison': 1.0,
#   'la': 1.0,
#   'tremendous': 1.0,
#   'putinplant': 1.0,
#   'patriarchal': 1.0,
#   'smooth': 1.0,
#   'last': 2.0,
#   'sunbury': 1.0,
#   'against': 1.0,
#   'gracemugabe': 1.0,
#   'hiv': 1.0,
#   'blacksupremacist': 1.0,
#   'israelis': 1.0,
#   'by': 1.0,
#   'give': 1.0,
#   'itstheendoftheworldand': 1.0,
#   'had': 1.0,
#   'auspo': 1.0,
#   'wakemeupwhen': 1.0,
#   'dylann': 1.0,
#   'innocent': 1.0,
#   'despite': 1.0,
#   'special': 1.0,
#   'arabs': 2.0,
#   'let': 3.0,
#   'watch': 2.0,
#   'jokes': 1.0,
#   'absurd': 1.0,
#   'dumbest': 1.0,
#   'birmingham': 1.0,
#   'arise': 1.0,
#   'michelle': 3.0,
#   'presidenttrump': 1.0,
#   'bama': 2.0,
#   'brutality': 1.0,
#   'ku': 1.0,
#   'sexism': 1.0,
#   'powerful': 1.0,
#   'realhousewives': 1.0,
#   'storyville': 1.0,
#   'watching': 1.0,
#   'crooked': 1.0,
#   'to': 1.0,
#   'imagine': 1.0,
#   'an': 2.0,
#   'maybe': 1.0,
#   'americans': 1.0,
#   'history': 3.0,
#   'pres': 1.0,
#   'worked': 1.0,
#   'louisville': 1.0,
#   'top': 1.0,
#   'stlouis': 1.0,
#   'antics': 1.0,
#   'blackface': 2.0,
#   'rapeculture': 1.0,
#   'liz': 2.0,
#   'hows': 1.0,
#   'tackling': 1.0,
#   'naked': 2.0,
#   'retweeted': 1.0,
#   'his': 1.0,
#   'empowerment': 1.0,
#   'whitepeople': 1.0,
#   'neogaf': 1.0,
#   'pmet': 1.0,
#   'perfect': 2.0,
#   'once': 1.0,
#   'funny': 1.0,
#   'cover': 1.0,
#   'btw': 3.0,
#   'they': 1.0,
#   'hard': 1.0,
#   'bill': 1.0,
#   'highlights': 1.0,
#   'scientists': 1.0,
#   'um': 1.0,
#   'approx': 1.0,
#   'alapoet': 1.0,
#   'given': 1.0,
#   'look': 1.0,
#   'be': 1.0,
#   'mmusimaimane': 2.0,
#   'damning': 1.0,
#   'imwithher': 1.0,
#   'fine': 1.0,
#   'office': 1.0,
#   'israeli': 1.0,
#   'hrs': 1.0,
#   'probably': 1.0,
#   'fakenews': 1.0,
#   'irony': 1.0,
#   'transsexy': 1.0,
#   'nobdy': 1.0,
#   'destroyed': 1.0,
#   'mother': 1.0,
#   'impoant': 1.0,
#   'anothr': 1.0,
#   'assholes': 1.0,
#   'conormcgregor': 1.0,
#   'isn': 2.0,
#   'verified': 1.0,
#   'milo': 1.0,
#   'princess': 1.0,
#   'goodonedean': 1.0,
#   'mark': 1.0,
#   'misogony': 1.0,
#   'crackers': 1.0,
#   'finally': 1.0,
#   'unbelievable': 1.0,
#   'need': 1.0,
#   'dearfellowwhitepeople': 1.0,
#   'couldn': 1.0,
#   'attack': 1.0,
#   'prank': 1.0,
#   'spread': 1.0,
#   'fair': 1.0,
#   'jokeoftheday': 1.0,
#   'another': 1.0,
#   'yeah': 1.0,
#   'pre': 1.0,
#   'burbank': 1.0,
#   'southsudan': 1.0,
#   'meanwhile': 1.0,
#   'andysessions': 1.0,
#   'nude': 1.0,
#   'vestal': 1.0,
#   'time': 1.0,
#   'wife': 1.0,
#   'strangely': 1.0,
#   'perpetuates': 1.0,
#   'nosurprise': 1.0,
#   'chomsky': 1.0,
#   'agreed': 2.0,
#   'billionaire': 1.0,
#   'happyholidays': 1.0,
#   'judge': 1.0,
#   'popefrancis': 1.0,
#   'lol': 1.0,
#   'boycotttigerwoods': 1.0,
#   'zionism': 2.0,
#   'bruh': 1.0,
#   'katiesikphoto': 1.0,
#   'prince': 1.0,
#   'sure': 1.0,
#   'ignorant': 1.0,
#   'john': 1.0,
#   'openly': 1.0,
#   'goodbye': 1.0,
#   'activists': 1.0,
#   'greetings': 1.0,
#   'dwyane': 1.0,
#   'antisemitism': 1.0,
#   'ways': 1.0,
#   'sessions': 1.0,
#   'hatred': 1.0,
#   'bringing': 1.0,
#   'see': 1.0,
#   'dr': 1.0,
#   'judd': 1.0,
#   'lady': 1.0,
#   'omfg': 1.0},
#  ('.', 'no'): {'comment': 2.0,
#   'he': 1.0,
#   'im': 1.0,
#   'racist': 1.0,
#   'liberal': 3.0,
#   'hitler': 1.0,
#   'it': 1.0,
#   'balls': 1.0,
#   'the': 1.0,
#   'u': 1.0,
#   'joking': 2.0,
#   'immigration': 1.0,
#   'we': 2.0,
#   'more': 1.0,
#   'jissus': 1.0,
#   'or': 1.0,
#   'such': 1.0,
#   'joke': 1.0,
#   'you': 1.0,
#   'convo': 1.0,
#   'as': 1.0},
#  ('no',): {'comment': 2.0,
#   'bet': 1.0,
#   'hope': 1.0,
#   'he': 1.0,
#   'im': 2.0,
#   'racist': 1.0,
#   'space': 2.0,
#   'liberal': 3.0,
#   'hitler': 1.0,
#   'time': 2.0,
#   'brown': 1.0,
#   'good': 1.0,
#   'notmypres': 3.0,
#   'i': 1.0,
#   'brain': 1.0,
#   'fat': 2.0,
#   'one': 8.0,
#   'it': 1.0,
#   'difference': 2.0,
#   'bp': 1.0,
#   'correlation': 1.0,
#   'balls': 2.0,
#   'the': 1.0,
#   'longer': 3.0,
#   'u': 1.0,
#   'joking': 2.0,
#   'immigration': 1.0,
#   'we': 2.0,
#   'more': 1.0,
#   'jissus': 1.0,
#   'consideration': 1.0,
#   'sees': 1.0,
#   'red': 1.0,
#   'surprise': 3.0,
#   'worse': 1.0,
#   'or': 1.0,
#   'apaheid': 1.0,
#   'to': 1.0,
#   'such': 2.0,
#   'safe': 1.0,
#   'non': 1.0,
#   'matter': 1.0,
#   'pt': 1.0,
#   'economic': 1.0,
#   'black': 1.0,
#   'joke': 1.0,
#   'texas': 1.0,
#   'way': 1.0,
#   'consequences': 1.0,
#   'basis': 1.0,
#   'problem': 1.0,
#   'you': 1.0,
#   'convo': 1.0,
#   'mystery': 1.0,
#   'media': 1.0,
#   'rational': 1.0,
#   'mandate': 1.0,
#   'business': 1.0,
#   'evidence': 1.0,
#   'as': 1.0},
#  ('no', 'comment'): {'in': 2.0},
#  ('comment',): {'in': 2.0,
#   'was': 1.0,
#   'again': 1.0,
#   'white': 1.0,
#   'on': 3.0,
#   'donation': 2.0,
#   'about': 1.0,
#   'towards': 1.0},
#  ('comment', 'in'): {'australia': 2.0},
#  ('in',): {'australia': 3.0,
#   'the': 55.0,
#   'a': 22.0,
#   'that': 4.0,
#   'hateful': 1.0,
#   'viral': 3.0,
#   'how': 2.0,
#   'any': 1.0,
#   'worlds': 1.0,
#   'words': 20.0,
#   'uk': 2.0,
#   'yur': 1.0,
#   'order': 1.0,
#   'in': 27.0,
#   'calgary': 27.0,
#   'belgian': 3.0,
#   'equality': 3.0,
#   'academia': 1.0,
#   'same': 2.0,
#   'never': 1.0,
#   'this': 5.0,
#   'military': 3.0,
#   'power': 3.0,
#   'i': 1.0,
#   'america': 11.0,
#   '.': 11.0,
#   'april': 1.0,
#   'eu': 2.0,
#   'me': 2.0,
#   'nyc': 3.0,
#   'march': 2.0,
#   'january': 2.0,
#   'judea': 1.0,
#   'science': 1.0,
#   'your': 4.0,
#   'cow': 1.0,
#   'saying': 1.0,
#   'we': 1.0,
#   'india': 4.0,
#   'schools': 1.0,
#   'th': 1.0,
#   'ceain': 1.0,
#   'arms': 2.0,
#   'being': 1.0,
#   'his': 5.0,
#   'plettenburgbay': 2.0,
#   'everything': 1.0,
#   'mind': 1.0,
#   'headlock': 1.0,
#   'atlanta': 1.0,
#   'word': 1.0,
#   'september': 1.0,
#   'what': 1.0,
#   'common': 3.0,
#   'last': 4.0,
#   'quebec': 1.0,
#   'trumpsamerica': 1.0,
#   'da': 2.0,
#   'trumpproofamerica': 1.0,
#   'men': 2.0,
#   'iwantto': 1.0,
#   'end': 1.0,
#   'who': 1.0,
#   'line': 1.0,
#   'racism': 3.0,
#   'porn': 1.0,
#   'cologne': 4.0,
#   'case': 1.0,
#   'itself': 1.0,
#   'deming': 1.0,
#   'n': 1.0,
#   'fraud': 1.0,
#   'ny': 1.0,
#   'my': 4.0,
#   'history': 5.0,
#   'japan': 5.0,
#   'wish': 2.0,
#   'emiratis': 1.0,
#   'chief': 1.0,
#   'one': 3.0,
#   'or': 1.0,
#   'newyork': 1.0,
#   'best': 1.0,
#   'ufc': 1.0,
#   'is': 1.0,
#   'hollywood': 2.0,
#   'you': 4.0,
#   'office': 1.0,
#   'whitefish': 1.0,
#   'black': 2.0,
#   'isr': 1.0,
#   'qatar': 1.0,
#   'highfashion': 2.0,
#   'georgia': 1.0,
#   'us': 1.0,
#   'avoice': 1.0,
#   'east': 1.0,
#   'obamanation': 1.0,
#   'these': 2.0,
#   'jewworldorder': 1.0,
#   'traffic': 1.0,
#   'emojis': 1.0,
#   'election': 1.0,
#   'our': 2.0,
#   'beauty': 1.0,
#   'different': 1.0,
#   'slavery': 1.0,
#   'policing': 1.0,
#   'jumpedthesh': 1.0,
#   'turn': 1.0,
#   'f': 1.0,
#   'pueorico': 3.0,
#   'american': 1.0,
#   'circle': 1.0,
#   'journalism': 1.0,
#   'virginia': 2.0,
#   'many': 2.0,
#   'promotions': 1.0,
#   'sexualbullying': 1.0,
#   'muslim': 1.0,
#   'whose': 1.0,
#   'and': 1.0,
#   'first': 1.0,
#   'harlem': 1.0,
#   'if': 1.0,
#   'their': 1.0,
#   'an': 1.0,
#   'edinburgh': 1.0,
#   'god': 1.0,
#   'health': 1.0,
#   'trump': 3.0,
#   'most': 2.0,
#   'civil': 2.0,
#   'media': 1.0,
#   'buffalo': 1.0,
#   'complementarianism': 1.0,
#   'revolution': 2.0,
#   'milwaukee': 1.0,
#   'promoting': 1.0,
#   'norrisgreen': 1.0,
#   'reagan': 1.0,
#   'new': 2.0,
#   'prison': 2.0,
#   'twitter': 1.0,
#   'prayer': 1.0,
#   'months': 2.0,
#   'aberrant': 1.0,
#   'em': 1.0,
#   'islamic': 1.0,
#   'buttoning': 1.0,
#   'for': 1.0,
#   'charging': 2.0,
#   'fact': 1.0,
#   'single': 1.0,
#   'reality': 1.0,
#   'bluntly': 2.0,
#   'heels': 2.0,
#   'jerusalem': 1.0,
#   'europe': 2.0,
#   'by': 1.0,
#   'southafrica': 2.0,
#   'trumpworld': 1.0,
#   'so': 1.0,
#   'various': 1.0,
#   'naboomspruit': 1.0,
#   'check': 1.0,
#   'after': 1.0,
#   'arabic': 1.0,
#   'thailand': 1.0,
#   'her': 1.0,
#   'hull': 1.0,
#   'h': 1.0,
#   'bed': 2.0,
#   'let': 1.0,
#   'queue': 1.0,
#   'ageism': 1.0,
#   'germany': 1.0,
#   'discrimination': 1.0,
#   'terms': 1.0,
#   'south': 1.0,
#   'marketing': 1.0,
#   'spo': 1.0,
#   'racist': 1.0,
#   'cou': 1.0,
#   'africa': 1.0,
#   'pubfriction': 1.0,
#   'view': 1.0,
#   'reach': 1.0,
#   'sunderland': 1.0,
#   'u': 1.0,
#   'lies': 1.0,
#   'remember': 1.0,
#   'syria': 1.0,
#   'jumpedtheshark': 1.0},
#  ('in', 'australia'): {'opkillingbay': 2.0, '.': 1.0},
#  ('australia',): {'opkillingbay': 2.0,
#   'and': 3.0,
#   '.': 1.0,
#   'refugeeswelcome': 1.0},
#  ('australia', 'opkillingbay'): {'seashepherd': 2.0},
#  ('opkillingbay',): {'seashepherd': 3.0, 'thecove': 2.0},
#  ('opkillingbay', 'seashepherd'): {'helpcovedolphins': 2.0, 'israeli': 1.0},
#  ('seashepherd',): {'helpcovedolphins': 2.0,
#   '.': 17.0,
#   'antiracism': 2.0,
#   'israeli': 1.0},
#  ('seashepherd', 'helpcovedolphins'): {'thecove': 2.0},
#  ('helpcovedolphins',): {'thecove': 2.0, '.': 1.0},
#  ('helpcovedolphins', 'thecove'): {'helpcovedolphins': 1.0, 'redcove': 1.0},
#  ('thecove',): {'helpcovedolphins': 1.0,
#   'shabbatshalom': 1.0,
#   'boycottaustralia': 1.0,
#   'redcove': 1.0},
#  ('thecove', 'helpcovedolphins'): {'.': 1.0},
#  ('helpcovedolphins', '.'): {'retweet': 1.0},
#  ('.', 'retweet'): {'if': 1.0, 'like': 1.0},
#  ('retweet',): {'if': 1.0,
#   'tampa': 32.0,
#   'boricua': 24.0,
#   '.': 7.0,
#   'like': 1.0,
#   'this': 1.0,
#   'video': 1.0},
#  ('retweet', 'if'): {'you': 1.0},
#  ('if',): {'you': 30.0,
#   'libtard': 72.0,
#   'i': 8.0,
#   'potus': 1.0,
#   'there': 1.0,
#   'talking': 1.0,
#   'someone': 1.0,
#   'itz': 1.0,
#   'the': 4.0,
#   'is': 1.0,
#   'kellyann': 1.0,
#   'any': 2.0,
#   'reginald': 1.0,
#   'clintons': 1.0,
#   'ur': 1.0,
#   'he': 1.0,
#   'refuted': 2.0,
#   'krakow': 1.0,
#   'in': 3.0,
#   'not': 1.0,
#   'we': 2.0,
#   'they': 4.0,
#   'people': 2.0,
#   'michelle': 1.0,
#   'murray': 1.0,
#   'only': 1.0,
#   'it': 2.0,
#   'obama': 1.0,
#   'reel': 1.0,
#   'a': 2.0,
#   '.': 1.0,
#   'that': 2.0,
#   'she': 1.0,
#   'rapists': 1.0,
#   'pisses': 1.0},
#  ('if', 'you'): {'agree': 1.0,
#   'hold': 1.0,
#   'say': 2.0,
#   'didn': 1.0,
#   'look': 1.0,
#   'are': 11.0,
#   'truly': 1.0,
#   'really': 1.0,
#   'get': 1.0,
#   'know': 1.0,
#   're': 4.0,
#   'think': 2.0,
#   'voted': 1.0,
#   'don': 1.0,
#   'hate': 1.0},
#  ('you',): {'agree': 1.0,
#   'can': 17.0,
#   'call': 3.0,
#   'point': 1.0,
#   'jewishsupremacist': 1.0,
#   'might': 72.0,
#   'hold': 1.0,
#   'never': 2.0,
#   'are': 41.0,
#   're': 34.0,
#   'promise': 2.0,
#   'black': 24.0,
#   'retweet': 5.0,
#   'praised': 1.0,
#   'from': 1.0,
#   'the': 4.0,
#   'keep': 3.0,
#   'to': 8.0,
#   'bigot': 1.0,
#   'no': 2.0,
#   'say': 6.0,
#   'didn': 1.0,
#   'liberals': 2.0,
#   'have': 6.0,
#   'returning': 1.0,
#   'at': 1.0,
#   'than': 1.0,
#   'listen': 49.0,
#   'so': 3.0,
#   'look': 1.0,
#   'thing': 1.0,
#   '.': 5.0,
#   'hispanic': 21.0,
#   'knew': 1.0,
#   'were': 1.0,
#   'suppo': 2.0,
#   'back': 2.0,
#   'that': 1.0,
#   'be': 1.0,
#   'know': 4.0,
#   'tweet': 3.0,
#   'may': 2.0,
#   'mr': 1.0,
#   'risk': 1.0,
#   'chauvinist': 1.0,
#   'misogynist': 1.0,
#   'punks': 1.0,
#   'did': 1.0,
#   'don': 5.0,
#   'truly': 1.0,
#   'a': 2.0,
#   'sure': 1.0,
#   'even': 1.0,
#   'rich': 1.0,
#   'vote': 2.0,
#   'it': 1.0,
#   'came': 1.0,
#   'win': 1.0,
#   'race': 1.0,
#   'all': 4.0,
#   'here': 3.0,
#   'jewish': 1.0,
#   'piece': 1.0,
#   'seriously': 1.0,
#   'unless': 1.0,
#   'ever': 2.0,
#   'accurately': 1.0,
#   'please': 1.0,
#   'want': 3.0,
#   'whom': 1.0,
#   'just': 3.0,
#   'will': 6.0,
#   'grenades': 1.0,
#   'stupid': 2.0,
#   'people': 1.0,
#   'forgot': 3.0,
#   'said': 1.0,
#   'tweeted': 1.0,
#   'preach': 1.0,
#   'in': 1.0,
#   'question': 1.0,
#   'sara': 1.0,
#   'they': 1.0,
#   'd': 1.0,
#   'should': 4.0,
#   'promote': 1.0,
#   'saying': 1.0,
#   'need': 4.0,
#   'any': 2.0,
#   'really': 1.0,
#   'assholes': 1.0,
#   'on': 1.0,
#   'get': 2.0,
#   'better': 1.0,
#   'comrade': 1.0,
#   'allow': 1.0,
#   'bitter': 1.0,
#   'feel': 1.0,
#   'missing': 1.0,
#   'jew': 1.0,
#   'wanna': 1.0,
#   'opt': 1.0,
#   'your': 1.0,
#   'with': 1.0,
#   'projecting': 1.0,
#   'see': 1.0,
#   'make': 1.0,
#   'and': 1.0,
#   'would': 1.0,
#   'do': 3.0,
#   'think': 4.0,
#   'mean': 2.0,
#   'go': 2.0,
#   'you': 1.0,
#   'homophobic': 2.0,
#   'either': 1.0,
#   'areclueless': 1.0,
#   'comments': 1.0,
#   'sob': 1.0,
#   'ableism': 1.0,
#   'dontbuythesun': 2.0,
#   'had': 1.0,
#   'down': 1.0,
#   'engage': 1.0,
#   'dare': 1.0,
#   'for': 1.0,
#   'off': 2.0,
#   'this': 2.0,
#   've': 1.0,
#   'own': 1.0,
#   'inauguration': 1.0,
#   'ratings': 1.0,
#   'sleep': 1.0,
#   'sir': 1.0,
#   'islamophobic': 1.0,
#   'keeping': 1.0,
#   'before': 1.0,
#   'stand': 1.0,
#   'me': 1.0,
#   'stop': 1.0,
#   'got': 1.0,
#   'dude': 1.0,
#   'trump': 1.0,
#   'joined': 1.0,
#   'santa': 1.0,
#   'oughta': 1.0,
#   'hate': 2.0,
#   'total': 1.0,
#   'spread': 1.0,
#   'misogynists': 1.0,
#   'voted': 1.0,
#   'still': 1.0,
#   'sarcasm': 1.0,
#   'anti': 1.0,
#   'dont': 1.0,
#   'okay': 1.0,
#   'how': 1.0,
#   'ask': 1.0,
#   'god': 1.0},
#  ('you', 'agree'): {'.': 1.0},
#  ('agree',): {'.': 2.0,
#   'that': 2.0,
#   'she': 1.0,
#   'with': 1.0,
#   'but': 2.0,
#   'w': 1.0},
#  ('agree', '.'): {'lumpy': 1.0, 'carl': 1.0},
#  ('.', 'lumpy'): {'says': 1.0},
#  ('lumpy',): {'says': 1.0,
#   '.': 1.0,
#   'my': 1.0,
#   'tony': 2.0,
#   'bwahahahahaha': 1.0},
#  ('lumpy', 'says'): {'i': 1.0},
#  ('says',): {'i': 6.0,
#   'otherwise': 1.0,
#   'michelle': 1.0,
#   'he': 3.0,
#   'that': 1.0,
#   'renowned': 1.0,
#   'the': 1.0,
#   'fatty': 1.0,
#   'a': 2.0,
#   'against': 1.0,
#   'no': 1.0,
#   'backlash': 2.0,
#   'deseret': 1.0,
#   'zionism': 2.0,
#   'black': 2.0,
#   'who': 1.0,
#   'give': 1.0,
#   'they': 1.0,
#   'non': 1.0},
#  ('says', 'i'): {'am': 2.0, 'look': 2.0, 'm': 1.0, 'will': 1.0},
#  ('i',): {'am': 14.0,
#   'm': 39.0,
#   'voted': 4.0,
#   'vot': 1.0,
#   'don': 12.0,
#   've': 14.0,
#   'wear': 2.0,
#   'look': 3.0,
#   'guess': 3.0,
#   'liked': 1.0,
#   'blame': 1.0,
#   'tell': 1.0,
#   'call': 6.0,
#   'would': 4.0,
#   'd': 5.0,
#   'type': 1.0,
#   'hope': 3.0,
#   'still': 1.0,
#   'wish': 3.0,
#   'didn': 3.0,
#   'also': 2.0,
#   'cant': 1.0,
#   'felt': 1.0,
#   'see': 4.0,
#   'wanna': 1.0,
#   'thought': 3.0,
#   'agree': 7.0,
#   'can': 9.0,
#   'cud': 2.0,
#   'wud': 2.0,
#   'have': 10.0,
#   'mentioned': 1.0,
#   'find': 1.0,
#   'wasn': 1.0,
#   'saw': 1.0,
#   'love': 2.0,
#   'won': 3.0,
#   'mean': 2.0,
#   'know': 4.0,
#   '.': 2.0,
#   'live': 3.0,
#   'test': 1.0,
#   'was': 8.0,
#   'decided': 2.0,
#   'think': 1.0,
#   'despise': 2.0,
#   'say': 3.0,
#   'ever': 1.0,
#   'will': 5.0,
#   'do': 10.0,
#   'stood': 1.0,
#   'get': 1.0,
#   'noticed': 2.0,
#   'wonder': 1.0,
#   'wouldn': 2.0,
#   'really': 2.0,
#   'fought': 1.0,
#   'did': 1.0,
#   'hardly': 1.0,
#   'feel': 2.0,
#   'embrac': 1.0,
#   'cover': 1.0,
#   'label': 1.0,
#   'embrace': 1.0,
#   'checked': 1.0,
#   'dare': 1.0,
#   'married': 1.0,
#   'never': 3.0,
#   'only': 2.0,
#   'want': 4.0,
#   'n': 2.0,
#   'concur': 2.0,
#   'asked': 1.0,
#   'told': 1.0,
#   'hated': 1.0,
#   'almost': 1.0,
#   'wanted': 1.0,
#   'hate': 4.0,
#   'take': 1.0,
#   'we': 1.0,
#   'could': 1.0,
#   'repeat': 2.0,
#   'work': 1.0,
#   'll': 2.0,
#   'designed': 1.0,
#   'got': 1.0,
#   'bet': 1.0,
#   'gotta': 1.0,
#   'suppo': 1.0,
#   'care': 1.0,
#   'now': 1.0,
#   'just': 2.0,
#   'definitely': 1.0,
#   'couldn': 1.0,
#   'then': 1.0,
#   'anybody': 1.0},
#  ('i', 'am'): {'a': 2.0,
#   'not': 4.0,
#   'disgusted': 1.0,
#   'making': 1.0,
#   'i': 1.0,
#   'waiting': 1.0,
#   'none': 1.0,
#   'helping': 1.0,
#   'just': 1.0,
#   'to': 1.0},
#  ('am',): {'a': 2.0,
#   'not': 4.0,
#   'et': 1.0,
#   'disgusted': 1.0,
#   'making': 1.0,
#   'i': 3.0,
#   'waiting': 1.0,
#   'none': 1.0,
#   'helping': 1.0,
#   'just': 1.0,
#   'to': 1.0},
#  ('am', 'a'): {'prove': 2.0},
#  ('a',): {'prove': 2.0,
#   'linguistics': 1.0,
#   'republican': 11.0,
#   'gorilla': 3.0,
#   'libtard': 72.0,
#   'door': 1.0,
#   'woman': 13.0,
#   'nice': 1.0,
#   'troll': 4.0,
#   'codeword': 1.0,
#   'consent': 1.0,
#   'and': 2.0,
#   'bigot': 7.0,
#   'openly': 1.0,
#   'white': 12.0,
#   'mexican': 1.0,
#   'stand': 1.0,
#   'video': 1.0,
#   'business': 5.0,
#   'city': 1.0,
#   'a': 3.0,
#   'misogynist': 1.0,
#   'very': 2.0,
#   'new': 9.0,
#   'joke': 4.0,
#   'pussy': 1.0,
#   'different': 1.0,
#   'few': 6.0,
#   'must': 2.0,
#   'muslim': 2.0,
#   'tra': 2.0,
#   'refugee': 1.0,
#   'problem': 3.0,
#   'popular': 2.0,
#   'an': 1.0,
#   'warmonger': 1.0,
#   'worlddanger': 1.0,
#   'non': 4.0,
#   'cake': 1.0,
#   'person': 2.0,
#   'dystopian': 2.0,
#   'nazi': 2.0,
#   'sharp': 2.0,
#   'critical': 1.0,
#   'bigoted': 1.0,
#   'thing': 3.0,
#   'shit': 1.0,
#   'violent': 1.0,
#   'girl': 2.0,
#   'douchebag': 1.0,
#   'substantive': 1.0,
#   'point': 1.0,
#   'legislature': 1.0,
#   'game': 2.0,
#   'complete': 1.0,
#   'black': 8.0,
#   'whitesupremacy': 1.0,
#   'goon': 1.0,
#   'damned': 2.0,
#   'platform': 1.0,
#   'matter': 1.0,
#   'for': 2.0,
#   'cute': 1.0,
#   'racist': 14.0,
#   'talented': 1.0,
#   'close': 1.0,
#   'world': 2.0,
#   'feminist': 3.0,
#   'good': 4.0,
#   'mating': 1.0,
#   'pig': 1.0,
#   'hyena': 1.0,
#   'slug': 1.0,
#   'meme': 1.0,
#   'grp': 2.0,
#   'young': 1.0,
#   'time': 1.0,
#   'survivor': 1.0,
#   'serious': 1.0,
#   'man': 7.0,
#   'race': 6.0,
#   'winner': 4.0,
#   'restaurant': 1.0,
#   't': 1.0,
#   'nigga': 2.0,
#   'fan': 1.0,
#   'look': 1.0,
#   'wog': 1.0,
#   'lady': 1.0,
#   'voice': 1.0,
#   'hopeful': 4.0,
#   '.': 11.0,
#   'hole': 2.0,
#   'crapsac': 1.0,
#   'language': 1.0,
#   'president': 3.0,
#   'biher': 1.0,
#   'but': 2.0,
#   'like': 1.0,
#   'loser': 1.0,
#   'big': 1.0,
#   'strong': 4.0,
#   'brain': 2.0,
#   'asshole': 1.0,
#   'jew': 2.0,
#   'nig': 1.0,
#   'it': 1.0,
#   'whiteperson': 1.0,
#   'private': 1.0,
#   'nation': 2.0,
#   'hispanic': 1.0,
#   'get': 1.0,
#   'shame': 1.0,
#   'logic': 2.0,
#   'role': 1.0,
#   'completely': 1.0,
#   'manmade': 1.0,
#   'student': 1.0,
#   'gay': 1.0,
#   'supermistict': 1.0,
#   'well': 1.0,
#   'drink': 1.0,
#   'raging': 1.0,
#   'performance': 1.0,
#   'lying': 1.0,
#   'house': 2.0,
#   'fascist': 4.0,
#   'reaction': 1.0,
#   'payday': 1.0,
#   'muthafucka': 1.0,
#   'substantially': 1.0,
#   'not': 3.0,
#   'provincial': 1.0,
#   'cockwomble': 1.0,
#   'ww': 1.0,
#   'celtic': 1.0,
#   'fake': 2.0,
#   'scapegoat': 1.0,
#   'drill': 1.0,
#   'gweh': 3.0,
#   'cave': 1.0,
#   'high': 1.0,
#   'fat': 2.0,
#   'multi': 1.0,
#   'total': 1.0,
#   'treacherous': 2.0,
#   'straght': 1.0,
#   'disgusting': 3.0,
#   'great': 3.0,
#   'qualifications': 1.0,
#   'reminder': 2.0,
#   'e': 5.0,
#   'distant': 1.0,
#   'quick': 1.0,
#   'hatred': 1.0,
#   'narcissistic': 1.0,
#   'hostility': 1.0,
#   'classy': 1.0,
#   'public': 1.0,
#   'twisted': 1.0,
#   'really': 3.0,
#   'shiless': 2.0,
#   'stereotype': 1.0,
#   'bag': 1.0,
#   'form': 3.0,
#   'disgraceful': 1.0,
#   'mere': 1.0,
#   'liar': 1.0,
#   'novel': 1.0,
#   'self': 1.0,
#   'bit': 2.0,
#   'hero': 1.0,
#   'means': 1.0,
#   'human': 1.0,
#   'cop': 2.0,
#   'cuck': 1.0,
#   'color': 1.0,
#   'real': 3.0,
#   'land': 1.0,
#   'jewish': 2.0,
#   'swastika': 2.0,
#   'war': 1.0,
#   'fool': 2.0,
#   'moveable': 1.0,
#   'speech': 1.0,
#   'highly': 3.0,
#   'kumbaya': 2.0,
#   'single': 2.0,
#   'right': 2.0,
#   'vid': 1.0,
#   'stop': 1.0,
#   'crisis': 1.0,
#   'tv': 1.0,
#   'male': 2.0,
#   'berating': 1.0,
#   'broader': 1.0,
#   'system': 1.0,
#   'ivanka': 1.0,
#   'terrorist': 1.0,
#   'giant': 2.0,
#   'lobotomy': 1.0,
#   'plethora': 2.0,
#   'felony': 2.0,
#   'former': 1.0,
#   'chance': 2.0,
#   'country': 2.0,
#   'lesson': 2.0,
#   'commie': 2.0,
#   'position': 1.0,
#   'fellow': 1.0,
#   'photo': 1.0,
#   'peek': 1.0,
#   'lid': 1.0,
#   'charity': 1.0,
#   'homophobe': 1.0,
#   'massive': 1.0,
#   'negro': 1.0,
#   'servant': 1.0,
#   'pizza': 2.0,
#   'trump': 2.0,
#   'victim': 2.0,
#   'collection': 1.0,
#   'small': 1.0,
#   'guy': 1.0,
#   'child': 1.0,
#   'leb': 1.0,
#   'tweet': 1.0,
#   'hypocrite': 1.0,
#   'perfect': 1.0,
#   'reson': 1.0,
#   'condescending': 1.0,
#   'late': 1.0,
#   'sexist': 1.0,
#   'flight': 1.0,
#   'coronial': 2.0,
#   'wave': 1.0,
#   'lunatic': 1.0,
#   'wonderful': 1.0,
#   'craving': 1.0,
#   'sexualpredator': 1.0,
#   'left': 2.0,
#   'mayor': 1.0,
#   'then': 1.0,
#   'play': 1.0,
#   'stellar': 1.0,
#   'zionist': 1.0,
#   'nutshell': 1.0,
#   'billionaire': 1.0,
#   'christmassy': 1.0,
#   'powerful': 1.0,
#   'facemask': 1.0,
#   'that': 1.0,
#   'surprise': 1.0,
#   'journalist': 1.0,
#   'news': 1.0,
#   'minoritypresident': 1.0,
#   'bridge': 1.0,
#   'positive': 1.0,
#   'wh': 2.0,
#   'refresher': 1.0,
#   'gender': 1.0,
#   'shi': 1.0,
#   'performer': 1.0,
#   'revolution': 1.0,
#   'job': 1.0,
#   'lot': 5.0,
#   'word': 1.0,
#   'highstool': 1.0,
#   'gollybar': 1.0,
#   'path': 1.0,
#   'demoralizing': 1.0,
#   'better': 1.0,
#   'special': 2.0,
#   'terrible': 1.0,
#   'dive': 1.0,
#   'life': 1.0,
#   'hipster': 1.0,
#   'monster': 1.0,
#   'taxwriteoff': 1.0,
#   'who': 2.0,
#   'crony': 1.0,
#   'global': 2.0,
#   'repoer': 1.0,
#   'brief': 2.0,
#   'school': 1.0,
#   'group': 1.0,
#   'dick': 2.0,
#   'genealogy': 1.0,
#   'fucking': 1.0,
#   'deeper': 1.0,
#   'boy': 1.0,
#   'book': 2.0,
#   'coward': 1.0,
#   'animation': 1.0,
#   'so': 1.0,
#   'largely': 1.0,
#   'message': 1.0,
#   'in': 2.0,
#   'whitesupremacist': 1.0,
#   'victory': 1.0,
#   'sh': 1.0,
#   'hate': 1.0,
#   'traitor': 1.0,
#   'police': 1.0,
#   'poster': 1.0,
#   'spectrum': 1.0,
#   'company': 1.0,
#   'little': 1.0,
#   'useless': 1.0,
#   'trumptrain': 1.0,
#   'hatecrime': 1.0,
#   'cr': 1.0,
#   'smile': 1.0,
#   'first': 1.0,
#   'cent': 1.0,
#   'nano': 1.0,
#   'campaign': 1.0,
#   'racewar': 2.0,
#   'result': 2.0,
#   'story': 1.0,
#   'this': 1.0,
#   'communist': 1.0,
#   'drunk': 1.0,
#   'heater': 1.0,
#   'i': 1.0,
#   'danger': 1.0,
#   'pic': 1.0,
#   'korean': 1.0,
#   'sick': 1.0,
#   'period': 1.0,
#   'rare': 1.0,
#   'follow': 1.0,
#   'homophobic': 1.0,
#   'mailbox': 1.0},
#  ('a', 'prove'): {'it': 2.0},
#  ('prove',): {'it': 2.0, 'you': 1.0},
#  ('prove', 'it'): {'lumpy': 2.0},
#  ('it',): {'lumpy': 2.0,
#   's': 55.0,
#   '.': 11.0,
#   'is': 11.0,
#   'bluntly': 1.0,
#   'possible': 2.0,
#   'you': 4.0,
#   'autocorrects': 1.0,
#   'didn': 2.0,
#   'did': 2.0,
#   'the': 1.0,
#   'worst': 2.0,
#   'isn': 4.0,
#   'black': 1.0,
#   'to': 5.0,
#   'does': 1.0,
#   'leads': 1.0,
#   'should': 1.0,
#   'folx': 1.0,
#   'was': 4.0,
#   'days': 1.0,
#   'means': 1.0,
#   'wasn': 1.0,
#   'offical': 2.0,
#   'for': 2.0,
#   'has': 1.0,
#   'helps': 1.0,
#   'and': 4.0,
#   'happens': 1.0,
#   'causes': 1.0,
#   'impossible': 3.0,
#   'that': 4.0,
#   'forbidden': 1.0,
#   'so': 1.0,
#   'jew': 2.0,
#   'bustymilf': 1.0,
#   'doesn': 2.0,
#   'will': 3.0,
#   'cou': 1.0,
#   'feel': 1.0,
#   'give': 1.0,
#   'harder': 1.0,
#   'fell': 2.0,
#   'be': 2.0,
#   'haters': 1.0,
#   'christmas': 1.0,
#   'just': 1.0,
#   'again': 1.0,
#   'won': 1.0,
#   'wrong': 1.0,
#   'scalds': 1.0,
#   'aches': 1.0,
#   'it': 1.0,
#   'sounds': 2.0,
#   'can': 1.0,
#   'ad': 1.0,
#   'must': 1.0,
#   'yourself': 3.0,
#   'erica': 1.0,
#   'read': 1.0,
#   'maybe': 1.0,
#   'hube': 1.0,
#   'weren': 1.0,
#   'right': 1.0,
#   'every': 1.0,
#   'goes': 1.0,
#   'illegal': 1.0,
#   'whitefeminism': 1.0,
#   'would': 1.0,
#   'takes': 1.0,
#   'dummies': 1.0,
#   'acceptable': 1.0,
#   'comes': 1.0,
#   'treats': 1.0,
#   'pretty': 1.0,
#   'misogynist': 1.0,
#   'stas': 1.0,
#   'all': 2.0,
#   'seems': 2.0,
#   'pisses': 1.0,
#   'they': 1.0,
#   'in': 1.0,
#   'time': 2.0,
#   'ain': 1.0,
#   'grow': 1.0,
#   'feels': 1.0,
#   'only': 1.0,
#   'anyway': 1.0,
#   'about': 1.0,
#   'off': 1.0},
#  ('it', 'lumpy'): {'.': 1.0, 'bwahahahahaha': 1.0},
#  ('lumpy', '.'): {'it': 1.0},
#  ('.', 'it'): {'s': 15.0,
#   'isn': 1.0,
#   'does': 1.0,
#   'was': 1.0,
#   'is': 3.0,
#   'impossible': 1.0,
#   'and': 1.0},
#  ('it', 's'): {'unbelievable': 1.0,
#   'when': 1.0,
#   'a': 5.0,
#   'just': 2.0,
#   'the': 1.0,
#   'clear': 2.0,
#   'not': 7.0,
#   'unacceptable': 1.0,
#   'hard': 1.0,
#   'needed': 2.0,
#   'proof': 1.0,
#   'official': 1.0,
#   'obvious': 1.0,
#   'so': 2.0,
#   'gonna': 1.0,
#   'blatantly': 1.0,
#   'wrong': 2.0,
#   'ok': 1.0,
#   'about': 1.0,
#   'would': 1.0,
#   'there': 1.0,
#   'although': 1.0,
#   'no': 1.0,
#   'awarded': 1.0,
#   'time': 2.0,
#   'an': 2.0,
#   'up': 1.0,
#   'vital': 1.0,
#   'already': 1.0,
#   'true': 1.0,
#   'clearly': 1.0,
#   'been': 1.0,
#   'we': 1.0,
#   'great': 1.0,
#   'pro': 1.0,
#   'going': 1.0,
#   'never': 1.0,
#   'now': 1.0},
#  ('s',): {'unbelievable': 1.0,
#   'when': 1.0,
#   'a': 20.0,
#   'don': 1.0,
#   'over': 2.0,
#   'blogpost': 2.0,
#   'humanrights': 1.0,
#   'in': 1.0,
#   'no': 6.0,
#   'just': 2.0,
#   'suffrage': 1.0,
#   'immigration': 1.0,
#   'sexist': 1.0,
#   'hope': 2.0,
#   'the': 6.0,
#   '.': 8.0,
#   'entitlement': 1.0,
#   'clear': 2.0,
#   'rapacious': 4.0,
#   'etc': 1.0,
#   'not': 10.0,
#   'rife': 1.0,
#   'unacceptable': 1.0,
#   'video': 1.0,
#   'hard': 1.0,
#   'allies': 2.0,
#   'needed': 2.0,
#   'altright': 1.0,
#   'eve': 2.0,
#   'horrible': 2.0,
#   'ashamed': 1.0,
#   'done': 1.0,
#   'proof': 1.0,
#   'official': 1.0,
#   'to': 4.0,
#   'mother': 2.0,
#   'odd': 1.0,
#   'got': 2.0,
#   'empire': 1.0,
#   'facility': 2.0,
#   'bold': 1.0,
#   'alcohol': 1.0,
#   'america': 2.0,
#   'less': 1.0,
#   'hate': 1.0,
#   'cult': 2.0,
#   'reich': 1.0,
#   'wife': 1.0,
#   'obvious': 1.0,
#   'so': 2.0,
#   'how': 3.0,
#   'and': 1.0,
#   'gonna': 1.0,
#   'bih': 1.0,
#   'bloggersblast': 1.0,
#   'pivo': 1.0,
#   'wh': 2.0,
#   'ny': 2.0,
#   'compensatory': 1.0,
#   'past': 1.0,
#   'cathedral': 1.0,
#   'racist': 4.0,
#   'policies': 3.0,
#   'your': 1.0,
#   'blatantly': 1.0,
#   'bald': 1.0,
#   'said': 1.0,
#   'monetary': 1.0,
#   'freedoms': 1.0,
#   'why': 5.0,
#   'humiliating': 1.0,
#   'being': 1.0,
#   'mouthpiece': 2.0,
#   'wrong': 3.0,
#   'ok': 1.0,
#   'iconic': 1.0,
#   'transition': 1.0,
#   'comments': 4.0,
#   'about': 1.0,
#   'response': 3.0,
#   'including': 1.0,
#   'would': 1.0,
#   'sizes': 1.0,
#   'achilles': 1.0,
#   'there': 1.0,
#   'although': 1.0,
#   'chosen': 1.0,
#   'nice': 1.0,
#   'awarded': 1.0,
#   'attitude': 3.0,
#   'hair': 3.0,
#   'menorah': 1.0,
#   'home': 1.0,
#   'invisible': 1.0,
#   'unfair': 1.0,
#   'first': 2.0,
#   'too': 1.0,
#   'bestfeature': 1.0,
#   'capitol': 1.0,
#   'my': 1.0,
#   'time': 2.0,
#   'butt': 2.0,
#   'blog': 1.0,
#   'pornstars': 1.0,
#   'that': 1.0,
#   'harsh': 1.0,
#   'of': 1.0,
#   'rabid': 1.0,
#   'new': 2.0,
#   'choice': 1.0,
#   'an': 5.0,
#   'because': 1.0,
#   'work': 1.0,
#   'moto': 1.0,
#   'poweothewomen': 1.0,
#   'up': 1.0,
#   'vital': 1.0,
#   'influence': 1.0,
#   'years': 1.0,
#   'already': 1.0,
#   'who': 1.0,
#   'eurosceptic': 1.0,
#   'true': 1.0,
#   'death': 2.0,
#   'where': 1.0,
#   'laser': 1.0,
#   'customer': 1.0,
#   'insane': 1.0,
#   'clearly': 1.0,
#   'revolution': 1.0,
#   'right': 1.0,
#   'foolish': 1.0,
#   'been': 2.0,
#   'cabinet': 1.0,
#   'lost': 2.0,
#   'princecharles': 1.0,
#   'father': 1.0,
#   'pick': 1.0,
#   'racism': 1.0,
#   'mars': 2.0,
#   'we': 1.0,
#   'surface': 1.0,
#   'ugly': 1.0,
#   'mental': 1.0,
#   'marine': 1.0,
#   'favorite': 1.0,
#   'survived': 1.0,
#   'gov': 1.0,
#   'islamophobia': 2.0,
#   'never': 2.0,
#   'something': 1.0,
#   'great': 1.0,
#   'once': 1.0,
#   'da': 1.0,
#   'donkey': 1.0,
#   'pro': 1.0,
#   'history': 2.0,
#   'increased': 1.0,
#   'what': 1.0,
#   'it': 1.0,
#   'going': 1.0,
#   'do': 1.0,
#   'all': 1.0,
#   'shown': 1.0,
#   'acts': 1.0,
#   'guy': 1.0,
#   'appeal': 1.0,
#   'graceless': 1.0,
#   'worksheet': 1.0,
#   'one': 1.0,
#   'now': 1.0,
#   'repoingsystem': 1.0},
#  ('s', 'unbelievable'): {'that': 1.0},
#  ('unbelievable',): {'that': 1.0, 'chosen': 2.0, 'aicle': 1.0},
#  ('unbelievable', 'that'): {'in': 1.0},
#  ('that',): {'in': 1.0,
#   'doesn': 2.0,
#   's': 24.0,
#   'made': 1.0,
#   'kitchen': 1.0,
#   'the': 5.0,
#   'only': 6.0,
#   'sexist': 2.0,
#   'i': 5.0,
#   'defines': 1.0,
#   'lawrence': 1.0,
#   'blm': 2.0,
#   'logic': 1.0,
#   'there': 6.0,
#   'we': 4.0,
#   'ass': 2.0,
#   'hrc': 2.0,
#   'hired': 1.0,
#   'small': 1.0,
#   'threaten': 1.0,
#   'means': 1.0,
#   'men': 1.0,
#   'she': 1.0,
#   'jews': 2.0,
#   'has': 4.0,
#   'revealed': 1.0,
#   'whole': 3.0,
#   'a': 8.0,
#   'prompts': 1.0,
#   'hatred': 2.0,
#   'jeffery': 2.0,
#   'is': 9.0,
#   '.': 2.0,
#   'ovr': 1.0,
#   'against': 1.0,
#   'pos': 1.0,
#   'they': 2.0,
#   'zille': 1.0,
#   'belief': 1.0,
#   'blackpeople': 1.0,
#   'no': 1.0,
#   'filth': 1.0,
#   'type': 1.0,
#   'he': 2.0,
#   'painting': 1.0,
#   'everyone': 1.0,
#   'looks': 1.0,
#   'exists': 1.0,
#   'it': 2.0,
#   'long': 1.0,
#   'was': 3.0,
#   'our': 1.0,
#   'all': 2.0,
#   'per': 1.0,
#   'calls': 2.0,
#   'blacklivesmatter': 1.0,
#   'faced': 2.0,
#   'isn': 1.0,
#   'joint': 1.0,
#   'me': 1.0,
#   'hasn': 1.0,
#   'would': 2.0,
#   'makes': 2.0,
#   'considering': 1.0,
#   'voterid': 1.0,
#   'zionism': 1.0,
#   'andrew': 1.0,
#   'trump': 2.0,
#   'melted': 1.0,
#   'tcot': 1.0,
#   'bashing': 2.0,
#   'cat': 1.0,
#   'observation': 1.0,
#   'wig': 1.0,
#   'oh': 1.0,
#   'this': 2.0,
#   'whiteness': 1.0,
#   'needs': 1.0,
#   'sparks': 1.0,
#   'ugly': 1.0,
#   'because': 1.0,
#   'good': 4.0,
#   'white': 1.0,
#   'work': 1.0,
#   'systemicracism': 1.0,
#   'you': 1.0,
#   'mr': 1.0,
#   'proved': 1.0,
#   'deliberately': 2.0,
#   'disenfranchised': 1.0,
#   'people': 3.0,
#   'bit': 1.0,
#   'resultant': 1.0,
#   'like': 2.0,
#   'newyear': 1.0,
#   'teach': 1.0,
#   'hate': 1.0,
#   'bitch': 1.0,
#   'one': 1.0,
#   'term': 1.0,
#   'word': 1.0,
#   'via': 1.0,
#   'u': 1.0,
#   'says': 1.0,
#   'jihad': 1.0,
#   'want': 1.0,
#   'bangladeshis': 1.0,
#   'right': 1.0,
#   'of': 1.0,
#   'should': 1.0,
#   'hammock': 1.0},
#  ('that', 'in'): {'the': 1.0},
#  ('in', 'the'): {'st': 2.0,
#   'world': 9.0,
#   's': 3.0,
#   'advancement': 1.0,
#   'age': 2.0,
#   'gop': 1.0,
#   'kitchen': 1.0,
#   'eyes': 2.0,
#   'workplace': 3.0,
#   'music': 4.0,
#   'white': 2.0,
#   'league': 1.0,
#   'fuck': 1.0,
#   'news': 1.0,
#   'brexit': 1.0,
#   'united': 1.0,
#   'kid': 1.0,
#   'us': 1.0,
#   'day': 1.0,
#   'oven': 1.0,
#   'case': 1.0,
#   'lgbt': 1.0,
#   'ellicottsquarebuilding': 1.0,
#   'uk': 4.0,
#   'car': 1.0,
#   'face': 1.0,
#   'south': 1.0,
#   'great': 1.0,
#   'open': 1.0,
#   'second': 1.0,
#   'bin': 1.0,
#   'street': 1.0,
#   'gutter': 1.0},
#  ('the', 'st'): {'century': 2.0, 'to': 1.0},
#  ('st',): {'century': 2.0, 'mark': 1.0, 'louis': 1.0, 'to': 1.0, 'in': 1.0},
#  ('st', 'century'): {'we': 1.0, 'what': 1.0},
#  ('century',): {'we': 1.0, 'spain': 1.0, 'what': 1.0},
#  ('century', 'we'): {'d': 1.0},
#  ('we',): {'d': 1.0,
#   'can': 8.0,
#   'become': 3.0,
#   'the': 12.0,
#   'be': 1.0,
#   'have': 12.0,
#   'need': 8.0,
#   'are': 7.0,
#   'oppose': 2.0,
#   're': 20.0,
#   'hate': 2.0,
#   'were': 3.0,
#   've': 3.0,
#   'should': 6.0,
#   'accept': 6.0,
#   'want': 2.0,
#   'loudly': 1.0,
#   'don': 2.0,
#   'bless': 1.0,
#   'ever': 1.0,
#   'really': 1.0,
#   'cannot': 1.0,
#   'theresistance': 2.0,
#   'r': 2.0,
#   'like': 1.0,
#   'will': 2.0,
#   'didnt': 1.0,
#   'always': 1.0,
#   'just': 3.0,
#   'all': 1.0,
#   'might': 2.0,
#   'go': 2.0,
#   'do': 1.0,
#   'won': 3.0,
#   'think': 1.0,
#   'see': 1.0,
#   'get': 1.0,
#   'love': 1.0,
#   'live': 1.0,
#   'call': 1.0,
#   'must': 1.0,
#   'both': 1.0,
#   'because': 1.0,
#   'face': 1.0,
#   'entering': 1.0,
#   'realized': 2.0,
#   'lost': 1.0,
#   'run': 1.0,
#   'let': 2.0,
#   'leave': 1.0,
#   'find': 1.0},
#  ('we', 'd'): {'need': 1.0},
#  ('d',): {'need': 1.0,
#   'been': 1.0,
#   'investigate': 1.0,
#   'still': 1.0,
#   'posted': 1.0,
#   'have': 2.0,
#   '.': 3.0,
#   'messenger': 1.0,
#   'be': 1.0,
#   'w': 1.0,
# ...
#   'xenophobia': 1.0},
#  ('bigot', '.'): {'girls': 1.0,
#   'rushlimbaugh': 1.0,
#   'the': 1.0,
#   'new': 1.0,
#   'twitter': 1.0,
#   'trump': 1.0,
#   'put': 1.0,
#   'wtf': 1.0,
#   'commercial': 1.0,
#   'allahsoil': 1.0,
#   'here': 1.0,
#   'yeah': 1.0,
#   'zionism': 1.0},
#  ('.', 'girls'): {'in': 4.0},
#  ('girls', 'in'): {'the': 4.0, 'highfashion': 1.0, 'first': 1.0},
#  ('the', 'world'): {'sexy': 1.0,
#   'keeps': 1.0,
#   'in': 2.0,
#   '.': 6.0,
#   'nude': 1.0,
#   'natt': 1.0,
#   'through': 1.0,
#   'instead': 1.0,
#   'jgirl': 1.0,
#   'are': 1.0,
#   'is': 1.0,
#   'discrimination': 1.0},
#  ('world',): {'sexy': 1.0,
#   'keeps': 1.0,
#   'in': 2.0,
#   'where': 1.0,
#   'pay': 1.0,
#   '.': 7.0,
#   'nude': 1.0,
#   'like': 2.0,
#   'sex': 1.0,
#   'natt': 1.0,
#   'campaign': 1.0,
#   'through': 1.0,
#   'instead': 1.0,
#   'exit': 1.0,
#   'if': 1.0,
#   'jgirl': 1.0,
#   'are': 1.0,
#   'is': 1.0,
#   'discrimination': 1.0},
#  ('world', 'sexy'): {'mature': 1.0},
#  ('sexy',): {'mature': 1.0,
#   'latinas': 1.0,
#   'girls': 2.0,
#   'cora': 1.0,
#   '.': 2.0},
#  ('sexy', 'mature'): {'housewife': 1.0},
#  ('mature',): {'housewife': 1.0},
#  ('mature', 'housewife'): {'.': 1.0},
#  ('housewife',): {'.': 1.0},
#  ('housewife', '.'): {'i': 1.0},
#  ('i', 'don'): {'t': 12.0},
#  ('t', 'like'): {'the': 1.0, 'or': 1.0, 'obama': 1.0, 'her': 1.0, 'his': 1.0},
#  ('the', 'blacklivesmatter'): {'slogan': 1.0},
#  ('blacklivesmatter', 'slogan'): {'talk': 1.0},
#  ('slogan',): {'talk': 1.0},
#  ('slogan', 'talk'): {'about': 1.0},
#  ('talk',): {'about': 4.0, 'to': 3.0, '.': 1.0},
#  ('talk', 'about'): {'being': 1.0, 'or': 1.0, 'womenvote': 1.0, 'it': 1.0},
#  ('being', '.'): {'feminismiscancer': 1.0},
#  ('.', 'feminismiscancer'): {'feminismisterrorism': 20.0},
#  ('feminismiscancer',): {'feminismisterrorism': 20.0},
#  ('feminismiscancer', 'feminismisterrorism'): {'feminismmuktbharat': 20.0},
#  ('feminismisterrorism',): {'feminismmuktbharat': 20.0},
#  ('feminismisterrorism', 'feminismmuktbharat'): {'why': 20.0},
#  ('feminismmuktbharat',): {'why': 20.0},
#  ('feminismmuktbharat', 'why'): {'malevote': 20.0},
#  ('why', 'malevote'): {'is': 20.0},
#  ('malevote',): {'is': 20.0,
#   '.': 1.0,
#   'womenvote': 1.0,
#   'to': 1.0,
#   'htt': 1.0},
#  ('malevote', 'is'): {'ignored': 20.0},
#  ('is', 'ignored'): {'.': 20.0},
#  ('ignored',): {'.': 20.0},
#  ('ignored', '.'): {'fox': 1.0,
#   'tyler': 1.0,
#   'lessons': 1.0,
#   'racism': 1.0,
#   'new': 2.0,
#   'barack': 1.0,
#   'allahsoil': 2.0,
#   'coming': 1.0,
#   'back': 1.0,
#   'i': 1.0,
#   'hidden': 1.0,
#   'why': 1.0,
#   'fascism': 1.0,
#   'mother': 1.0,
#   'fo': 1.0,
#   'popefrancis': 1.0,
#   'he': 1.0,
#   'judd': 1.0},
#  ('.', 'fox'): {'new': 1.0, 'news': 1.0},
#  ('fox',): {'new': 1.0, 'news': 1.0},
#  ('fox', 'new'): {'just': 1.0},
#  ('new',): {'just': 1.0,
#   '.': 2.0,
#   'prez': 2.0,
#   'destruction': 2.0,
#   'commercials': 2.0,
#   'new': 2.0,
#   'order': 2.0,
#   'tweets': 2.0,
#   'poopin': 2.0,
#   'kids': 2.0,
#   'mc': 7.0,
#   'year': 10.0,
#   'yea': 1.0,
#   'video': 4.0,
#   'one': 2.0,
#   'kind': 4.0,
#   'york': 5.0,
#   'heights': 1.0,
#   'post': 1.0,
#   'yorkers': 2.0,
#   'america': 1.0,
#   'beginning': 1.0,
#   'ghostbusters': 1.0,
#   'anti': 2.0,
#   'religion': 1.0,
#   'release': 1.0,
#   'law': 1.0,
#   'black': 1.0,
#   'mexico': 2.0,
#   'dystopian': 1.0,
#   'competency': 1.0,
#   'paladino': 1.0,
#   'age': 1.0,
#   'that': 1.0},
#  ('new', 'just'): {'coming': 1.0},
#  ('just',): {'coming': 1.0,
#   'more': 1.0,
#   'a': 3.0,
#   'because': 3.0,
#   'to': 2.0,
#   'coz': 1.0,
#   'plain': 1.0,
#   'some': 1.0,
#   'not': 3.0,
#   'press': 1.0,
#   'look': 1.0,
#   'say': 3.0,
#   'cussed': 1.0,
#   'lasses': 1.0,
#   'stop': 1.0,
#   'leave': 1.0,
#   'humour': 1.0,
#   'in': 1.0,
#   'one': 1.0,
#   'asking': 1.0,
#   'listen': 1.0,
#   'delete': 2.0,
#   'bookpublishing': 1.0,
#   'slap': 2.0,
#   'bought': 2.0,
#   'don': 2.0,
#   'as': 3.0,
#   'may': 1.0,
#   'close': 1.0,
#   'about': 1.0,
#   'fuuuuuuuuuuuuck': 1.0,
#   'shameful': 1.0,
#   'pre': 2.0,
#   'their': 1.0,
#   'yelling': 1.0,
#   'misunderstood': 1.0,
#   'got': 3.0,
#   'saying': 1.0,
#   'trying': 1.0,
#   'learned': 1.0,
#   'had': 2.0,
#   'able': 1.0,
#   'c': 1.0,
#   'funny': 1.0,
#   'the': 2.0,
#   'supposed': 1.0,
#   'scared': 1.0,
#   'assume': 1.0,
#   'takin': 1.0,
#   'gender': 1.0,
#   'terming': 1.0,
#   'let': 1.0,
#   'humanity': 1.0,
#   'can': 1.0,
#   'like': 1.0,
#   'waiting': 1.0,
#   'chose': 1.0,
#   'hate': 1.0,
#   'attempted': 1.0},
#  ('just', 'coming'): {'out': 1.0},
#  ('coming',): {'out': 1.0, 'from': 4.0},
#  ('coming', 'out'): {'and': 1.0},
#  ('out', 'and'): {'saying': 1.0},
#  ('and', 'saying'): {'it': 1.0},
#  ('saying',): {'it': 2.0,
#   'they': 3.0,
#   'i': 3.0,
#   'ceain': 1.0,
#   'this': 1.0,
#   'kill': 1.0,
#   'only': 1.0,
#   'anything': 1.0,
#   'blacks': 1.0,
#   'the': 1.0,
#   'that': 1.0,
#   'he': 1.0,
#   'violently': 1.0,
#   'draintheswamp': 1.0,
#   'his': 1.0,
#   'notallmen': 1.0},
#  ('saying', 'it'): {'bluntly': 1.0, 'hube': 1.0},
#  ('it', 'bluntly'): {'one': 1.0},
#  ('bluntly',): {'one': 1.0, 'tweet': 1.0, 'language': 1.0},
#  ('bluntly', 'one'): {'of': 1.0},
#  ('one', 'of'): {'the': 6.0, 'her': 1.0, 'his': 1.0, 'those': 1.0, 'a': 1.0},
#  ('the', 'most'): {'things': 1.0,
#   'president': 1.0,
#   'effective': 1.0,
#   'hated': 1.0,
#   'wise': 1.0,
#   'innovative': 1.0,
#   'islamophobia': 1.0,
#   's': 1.0,
#   'loathsome': 1.0,
#   'destructive': 1.0,
#   'st': 1.0,
#   'antiwhite': 1.0},
#  ('most',): {'things': 1.0,
#   'likely': 2.0,
#   'president': 1.0,
#   'problems': 1.0,
#   'horrifying': 3.0,
#   'effective': 2.0,
#   'hated': 2.0,
#   'wise': 1.0,
#   'boys': 1.0,
#   'popular': 1.0,
#   'innovative': 1.0,
#   'islamophobia': 1.0,
#   'bigot': 1.0,
#   'country': 1.0,
#   's': 1.0,
#   'racist': 1.0,
#   'recent': 1.0,
#   'big': 2.0,
#   'deaths': 2.0,
#   'loathsome': 1.0,
#   'destructive': 1.0,
#   'victims': 1.0,
#   'video': 1.0,
#   'st': 1.0,
#   'antiwhite': 1.0},
#  ('most', 'things'): {'i': 1.0},
#  ('things',): {'i': 1.0,
#   'he': 1.0,
#   '.': 2.0,
#   'women': 1.0,
#   'whitepriv': 1.0,
#   'killallwhitemen': 1.0},
#  ('things', 'i'): {'ve': 1.0},
#  ('i', 've'): {'read': 1.0,
#   'begun': 1.0,
#   'had': 4.0,
#   'been': 1.0,
#   'met': 1.0,
#   'ever': 2.0,
#   'experienced': 1.0,
#   'beensqueezing': 1.0,
#   'always': 1.0,
#   'no': 1.0},
#  ('ve',): {'read': 1.0,
#   'begun': 1.0,
#   'been': 2.0,
#   'had': 4.0,
#   'given': 1.0,
#   'come': 1.0,
#   'met': 1.0,
#   'ever': 2.0,
#   'experienced': 1.0,
#   'beensqueezing': 1.0,
#   'already': 1.0,
#   'always': 1.0,
#   'no': 1.0,
#   'done': 2.0,
#   'went': 1.0},
#  ('ve', 'read'): {'.': 1.0},
#  ('read',): {'.': 2.0,
#   'brief': 1.0,
#   'this': 1.0,
#   'and': 1.0,
#   'more': 2.0,
#   'stupid': 1.0,
#   'for': 1.0,
#   'sdgs': 1.0,
#   'a': 1.0,
#   'america': 2.0},
#  ('read', '.'): {'yes': 1.0, 'will': 1.0},
#  ('yes', 'lets'): {'do': 1.0},
#  ('lets', 'do'): {'this': 1.0},
#  ('do', 'this'): {'suppoing': 1.0, 'need': 2.0, 'fuck': 1.0, 'maga': 1.0},
#  ('this', 'suppoing'): {'a': 1.0},
#  ('suppoing',): {'a': 1.0,
#   'her': 1.0,
#   'communism': 1.0,
#   'nazi': 1.0,
#   '.': 1.0},
#  ('suppoing', 'a'): {'openly': 1.0},
#  ('a', 'openly'): {'prowar': 1.0},
#  ('openly',): {'prowar': 1.0, 'opposed': 2.0, 'racist': 1.0, 'and': 1.0},
#  ('openly', 'prowar'): {'anti': 1.0},
#  ('prowar',): {'anti': 1.0},
#  ('prowar', 'anti'): {'islamic': 1.0},
#  ('anti', 'islamic'): {'homophobic': 1.0},
#  ('islamic',): {'homophobic': 1.0,
#   'terrorism': 2.0,
#   'extremism': 6.0,
#   'extremist': 1.0,
#   'extremists': 1.0},
#  ('islamic', 'homophobic'): {'rapist': 1.0},
#  ('homophobic',): {'rapist': 1.0,
#   'misogynist': 6.0,
#   'a': 1.0,
#   'theistic': 1.0,
#   'and': 1.0,
#   'misogynistic': 1.0,
#   'islamaphobic': 1.0,
#   'freemilo': 1.0},
#  ('homophobic', 'rapist'): {'who': 1.0},
#  ('rapist',): {'who': 1.0,
#   'is': 1.0,
#   'trumpuniversity': 1.0,
#   'egomaniac': 1.0,
#   'it': 1.0,
#   '.': 1.0,
#   'johnrkhoward': 1.0},
#  ('rapist', 'who'): {'advocates': 1.0},
#  ('who',): {'advocates': 1.0,
#   'grew': 2.0,
#   'are': 3.0,
#   'defines': 1.0,
#   'believes': 3.0,
#   'rejected': 7.0,
#   'was': 3.0,
#   'choked': 1.0,
#   'knows': 1.0,
#   'arnt': 1.0,
#   'the': 1.0,
#   'humiliated': 1.0,
#   'will': 1.0,
#   'shot': 1.0,
#   'used': 2.0,
#   's': 5.0,
#   'use': 1.0,
#   'treats': 1.0,
#   'came': 1.0,
#   'had': 2.0,
#   'call': 1.0,
#   'thinks': 1.0,
#   'said': 1.0,
#   'can': 1.0,
#   'should': 1.0,
#   'live': 1.0,
#   'is': 3.0,
#   'tweeted': 1.0,
#   'got': 1.0,
#   'their': 1.0,
#   'ain': 1.0,
#   'knew': 2.0,
#   'you': 1.0,
#   'says': 1.0,
#   'they': 1.0,
#   'my': 1.0,
#   '.': 4.0,
#   'agenda': 2.0,
#   'hates': 1.0,
#   'isn': 1.0,
#   'speak': 1.0,
#   'just': 1.0,
#   'discredit': 1.0,
#   'promote': 1.0,
#   'repoed': 1.0,
#   'find': 1.0,
#   'breathes': 1.0,
#   'pulled': 1.0,
#   'isnt': 1.0,
#   'lost': 1.0,
#   'do': 2.0,
#   'your': 1.0,
#   'sympathized': 1.0,
#   'answer': 1.0,
#   'voted': 1.0,
#   'lot': 2.0,
#   'goes': 2.0,
#   'suggests': 1.0,
#   'd': 1.0,
#   'he': 1.0,
#   'gives': 1.0,
#   'enable': 1.0,
#   'gave': 1.0,
#   'were': 1.0,
#   'am': 1.0},
#  ('who', 'advocates'): {'more': 1.0},
#  ('advocates',): {'more': 1.0},
#  ('advocates', 'more'): {'of': 1.0},
#  ('more', 'of'): {'same': 1.0, 'a': 1.0},
#  ('of', 'same'): {'hypocrite': 1.0},
#  ('same', 'hypocrite'): {'.': 1.0},
#  ('hypocrite',): {'.': 2.0, 'liar': 1.0, 'whitegenocide': 1.0},
#  ('hypocrite', '.'): {'porn': 1.0, 'peruvian': 1.0},
#  ('.', 'porn'): {'vids': 2.0, 'blue': 1.0, 'video': 1.0, 'videos': 3.0},
#  ('porn',): {'vids': 2.0,
#   'blue': 2.0,
#   'video': 5.0,
#   '.': 3.0,
#   'pics': 1.0,
#   'is': 1.0,
#   'link': 1.0,
#   'fetish': 1.0,
#   'videos': 3.0,
#   'teen': 1.0,
#   'free': 1.0,
#   'black': 1.0,
#   's': 1.0,
#   'thailand': 1.0},
#  ('porn', 'vids'): {'wwwsmallgirlsexcom': 1.0, 'web': 1.0},
#  ('vids',): {'wwwsmallgirlsexcom': 1.0,
#   'dont': 1.0,
#   'against': 1.0,
#   '.': 1.0,
#   'web': 1.0},
#  ('vids', 'wwwsmallgirlsexcom'): {'.': 1.0},
#  ('wwwsmallgirlsexcom',): {'.': 1.0},
#  ('wwwsmallgirlsexcom', '.'): {'the': 1.0},
#  ('the', 'latest'): {'obsidian': 1.0,
#   'the': 22.0,
#   'science': 1.0,
#   'ad': 1.0,
#   'socialmooc': 1.0,
#   'say': 1.0,
#   'eco': 1.0},
#  ('latest',): {'obsidian': 1.0,
#   'the': 22.0,
#   'science': 1.0,
#   'ad': 1.0,
#   'socialmooc': 1.0,
#   'amwriting': 2.0,
#   'post': 1.0,
#   'say': 1.0,
#   'tweet': 1.0,
#   'eco': 1.0},
#  ('latest', 'obsidian'): {'radio': 1.0},
#  ('obsidian',): {'radio': 1.0},
#  ('obsidian', 'radio'): {'daily': 1.0},
#  ('radio',): {'daily': 1.0, '.': 1.0, 'songwords': 1.0},
#  ('radio', 'daily'): {'thanks': 1.0},
#  ('daily',): {'thanks': 18.0, 'show': 2.0, 'news': 1.0, 'lynching': 1.0},
#  ('daily', 'thanks'): {'to': 18.0},
#  ('thanks',): {'to': 30.0, '.': 2.0},
#  ('thanks', 'to'): {'latesnews': 1.0,
#   'space': 1.0,
#   'chrismukkah': 1.0,
#   '.': 1.0,
#   'blm': 1.0,
#   'twitte': 1.0,
#   'all': 2.0,
#   'amandanunes': 1.0,
#   'ad': 1.0,
#   'africa': 1.0,
#   'feliz': 1.0,
#   'equality': 1.0,
#   'catalunya': 1.0,
#   'justjustice': 1.0,
#   'afghanistan': 1.0,
#   'trump': 1.0,
#   'you': 1.0,
#   'marketing': 2.0,
#   'healthy': 1.0,
#   'fostercare': 1.0,
#   'seahawks': 1.0,
#   'maga': 1.0,
#   'news': 1.0,
#   'media': 1.0,
#   'blacktwitter': 1.0,
#   'culturesways': 1.0,
#   'indigenous': 1.0,
#   'racists': 1.0},
#  ('to', 'latesnews'): {'.': 1.0},
#  ('latesnews',): {'.': 1.0},
#  ('latesnews', '.'): {'you': 1.0},
#  ('.', 'just'): {'more': 1.0,
#   'because': 1.0,
#   'coz': 1.0,
#   'some': 1.0,
#   'asking': 1.0,
#   'delete': 2.0,
#   'pre': 2.0,
#   'saying': 1.0,
#   'learned': 1.0,
#   'got': 2.0,
#   'terming': 1.0,
#   'like': 1.0},
#  ('just', 'more'): {'overwhelming': 1.0},
#  ('more', 'overwhelming'): {'evidence': 1.0},
#  ('overwhelming',): {'evidence': 1.0},
#  ('overwhelming', 'evidence'): {'that': 1.0},
#  ('evidence',): {'that': 1.0, 'of': 1.0, 'proved': 1.0, 'yet': 1.0},
#  ('evidence', 'that'): {'the': 1.0},
#  ('that', 'the'): {'company': 1.0, 'clock': 1.0, 'tech': 2.0, 'pap': 1.0},
#  ('the', 'company'): {'trump': 1.0},
#  ('company',): {'trump': 1.0, 'you': 2.0, 'rep': 1.0},
#  ('company', 'trump'): {'keeps': 1.0},
#  ('trump', 'keeps'): {'echoes': 1.0},
#  ('keeps',): {'echoes': 1.0, 'telling': 2.0, 'spinning': 1.0},
#  ('keeps', 'echoes'): {'his': 1.0},
#  ('echoes',): {'his': 1.0},
#  ('echoes', 'his'): {'sentiments': 1.0},
#  ('his', 'sentiments'): {'ideals': 1.0},
#  ('sentiments',): {'ideals': 1.0},
#  ('sentiments', 'ideals'): {'dumptrump': 1.0},
#  ('ideals',): {'dumptrump': 1.0},
#  ('ideals', 'dumptrump'): {'.': 1.0},
#  ('dumptrump',): {'.': 1.0, 'notmypresident': 1.0},
#  ('dumptrump', '.'): {'nigger': 1.0},
#  ('.', 'nigger'): {'lifelessons': 3.0, 'pattismith': 1.0},
#  ('nigger',): {'lifelessons': 3.0, 'pattismith': 1.0, 'to': 2.0},
#  ('nigger', 'lifelessons'): {'of': 3.0},
#  ('lifelessons',): {'of': 3.0},
#  ('lifelessons', 'of'): {'a': 2.0, 'white': 1.0},
#  ('of', 'a'): {'white': 2.0,
#   'game': 2.0,
#   'mating': 1.0,
#   'slug': 1.0,
#   'grp': 2.0,
#   'nation': 1.0,
#   'lying': 1.0,
#   'man': 1.0,
#   'payday': 1.0,
#   'human': 1.0,
#   'play': 1.0,
#   'racist': 1.0,
#   'crony': 1.0,
#   'repoer': 1.0,
#   'hatecrime': 1.0,
#   'special': 1.0,
#   'korean': 1.0,
#   'rare': 1.0},
#  ('a', 'white'): {'kid': 2.0,
#   'south': 1.0,
#   'after': 1.0,
#   'man': 1.0,
#   'guy': 1.0,
#   'skinned': 1.0,
#   'woman': 1.0,
#   'christmas': 1.0,
#   'hood': 2.0,
#   'mother': 1.0},
#  ('white', 'kid'): {'who': 2.0, 'growing': 1.0},
#  ('kid',): {'who': 2.0, 'growing': 1.0, 'littering': 1.0, 'ever': 1.0},
#  ('kid', 'who'): {'grew': 2.0},
#  ('who', 'grew'): {'up': 2.0},
#  ('grew',): {'up': 2.0},
#  ('grew', 'up'): {'in': 2.0},
#  ('up',): {'in': 8.0,
#   'to': 5.0,
#   'the': 2.0,
#   'with': 10.0,
#   'rat': 1.0,
#   'guns': 1.0,
#   'against': 1.0,
#   'why': 3.0,
#   'his': 2.0,
#   'pe': 1.0,
#   'a': 1.0,
#   'bestof': 1.0,
#   '.': 1.0,
#   'they': 2.0,
#   'today': 2.0,
#   'what': 1.0,
#   'as': 1.0,
#   'usa': 2.0,
#   'every': 1.0,
#   'from': 1.0},
#  ('up', 'in'): {'the': 3.0,
#   'arms': 2.0,
#   'september': 1.0,
#   'promotions': 1.0,
#   'racism': 1.0},
#  ('the', 's'): {'blogpost': 2.0, 'bloggersblast': 1.0},
#  ('s', 'blogpost'): {'whitepeople': 2.0},
#  ('blogpost',): {'whitepeople': 2.0},
#  ('blogpost', 'whitepeople'): {'respect': 2.0},
#  ('whitepeople',): {'respect': 2.0,
#   'hawaii': 1.0,
#   'ccot': 2.0,
#   'kanyewest': 1.0,
#   'and': 1.0,
#   '.': 1.0,
#   'all': 1.0},
#  ('whitepeople', 'respect'): {'.': 2.0},
#  ('respect',): {'.': 3.0, 'everydayheroes': 1.0, 'concept': 1.0},
#  ('respect', '.'): {'carolyn': 1.0, 'yoyas': 1.0, 'council': 1.0},
#  ('.', 'carolyn'): {'cooper': 1.0},
#  ('carolyn',): {'cooper': 1.0},
#  ('carolyn', 'cooper'): {'ugly': 1.0},
#  ('cooper',): {'ugly': 1.0},
#  ('cooper', 'ugly'): {'poor': 1.0},
#  ('ugly',): {'poor': 1.0,
#   'comments': 2.0,
#   'reprehensible': 1.0,
#   'mt': 1.0,
#   'lady': 1.0,
#   'prejudice': 1.0,
#   'skank': 1.0},
#  ('ugly', 'poor'): {'ignorant': 1.0},
#  ('poor',): {'ignorant': 1.0, 'like': 1.0, '.': 2.0, 'slavelabor': 1.0},
#  ('poor', 'ignorant'): {'and': 1.0},
#  ('ignorant',): {'and': 2.0,
#   'tacky': 1.0,
#   '.': 3.0,
#   'in': 3.0,
#   'pamelaramseytaylor': 1.0},
#  ('ignorant', 'and'): {'black': 1.0, 'vicious': 1.0},
#  ('and', 'black'): {'.': 1.0, 'people': 2.0, 'women': 1.0},
#  ('black', '.'): {'no': 1.0,
#   'if': 1.0,
#   'so': 1.0,
#   'great': 1.0,
#   'word': 1.0,
#   'good': 1.0},
#  ('no', 'he'): {'was': 1.0},
#  ('he',): {'was': 4.0,
#   'd': 3.0,
#   'staed': 2.0,
#   'discovered': 2.0,
#   'should': 2.0,
#   's': 13.0,
#   'is': 9.0,
#   'wants': 2.0,
#   'stood': 1.0,
#   'said': 1.0,
#   'loves': 1.0,
#   'will': 3.0,
#   'calls': 1.0,
#   'graduated': 1.0,
#   'and': 1.0,
#   'knew': 1.0,
#   'faced': 1.0,
#   'ignorantly': 1.0,
#   'does': 1.0,
#   'he': 1.0,
#   'committed': 1.0,
#   'redacts': 2.0,
#   'll': 1.0,
#   'once': 2.0,
#   'takes': 1.0,
#   'want': 1.0,
#   'white': 1.0,
#   'li': 1.0,
#   'spoke': 1.0,
#   'never': 2.0,
#   'expected': 1.0,
#   'has': 2.0,
#   'knows': 2.0,
#   'says': 2.0,
#   'won': 2.0,
#   'perhaps': 1.0,
#   'can': 2.0,
#   '.': 1.0,
#   'would': 1.0,
#   'must': 1.0,
#   'lie': 1.0,
#   'leaves': 1.0,
#   'heard': 1.0,
#   'did': 1.0,
#   'stands': 1.0,
#   'may': 2.0,
#   'have': 1.0,
#   'hopes': 1.0,
#   'ain': 1.0,
#   'isnt': 1.0,
#   'looks': 1.0,
#   'hates': 1.0},
#  ('he', 'was'): {'definitely': 1.0, 'thrown': 2.0, 'in': 1.0},
#  ('was', 'definitely'): {'a': 1.0},
#  ('definitely',): {'a': 1.0, 'not': 1.0, 'hope': 1.0},
#  ('definitely', 'a'): {'mexican': 1.0},
#  ('a', 'mexican'): {'fakenewsale': 1.0},
#  ('mexican',): {'fakenewsale': 1.0, 'as': 2.0, 'a': 1.0},
#  ('mexican', 'fakenewsale'): {'.': 1.0},
#  ('fakenewsale',): {'.': 1.0},
#  ('fakenewsale', '.'): {'standing': 1.0},
#  ('.', 'standing'): {'up': 1.0},
#  ('standing',): {'up': 1.0, 'american': 1.0, 'your': 1.0},
#  ...}

# %%
#extracting racist/sexist tweets
negativeTweets=train_clean[train_clean['label']==1]
newlyGeneratedTweets=pd.DataFrame()
#Repeat with the New Sentences for 3 times
for i in range(3):
    data = negativeTweets['tweet']
    markovLength = 2
    numberofsentences=data.size
    buildMapping(wordlist(data), markovLength)
    newTweets = []
    for i in range(numberofsentences):
        newTweet=genSentence(markovLength)
        # Sentence should have more than 10 chatachters
        if len(newTweet) > 15:
            newTweets.append(newTweet)
    d={'tweet':newTweets,'label':1}
    df=pd.DataFrame(data=d)
    newlyGeneratedTweets=newlyGeneratedTweets.append(df)
    newlyGeneratedTweets=newlyGeneratedTweets.reset_index()
    newlyGeneratedTweets=newlyGeneratedTweets.drop(['index'], axis=1)
    print(newlyGeneratedTweets.shape)
# Out:
# (2057, 2)
# (4101, 2)
# (6160, 2)

# %%
newlyGeneratedTweets.tail()
# Out:
#                                                                                                                       tweet  \
# 6155  All the way through jo.
# 6156  Isn t white i m constantly let down by the perks offered to passengers of the impoance of families familycircus chri.
# 6157  Comment donation for tefugeeswelcome sucks.
# 6158  Australia and japanese whaling opkillingbay thecove shabbatshalom.
# 6159  Feminismiscancer feminismisterrorism feminismmuktbharat why malevote is ignored.
#
#       label
# 6155  1
# 6156  1
# 6157  1
# 6158  1
# 6159  1

# %%
train_cl=train_clean.append(newlyGeneratedTweets)
#train_cl=train_cl.append(hateTweets)
train_cl=train_cl.drop(['id'], axis=1)
#Percentage of Positive/Negative
print("Positive: ", train_cl.label.value_counts()[0]/len(train_cl)*100,"%")
print("Negative: ", train_cl.label.value_counts()[1]/len(train_cl)*100,"%")
# Out:
# Positive:  77.9602329363622 %
# Negative:  22.039767063637793 %
# d:\anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
pl.countplot(train_cl["label"])

# %%
# Remove small tweets
train_cl=train_cl[train_cl['tweet'].str.len()>15]

# %%
x_train, x_test, y_train, y_test = train_test_split(train_cl['tweet'],train_cl['label'], test_size=0.33, random_state=42)

# %%
pr=Pipeline([('vect', CountVectorizer(ngram_range=(1, 2))),
                     ('tfidf', TfidfTransformer(use_idf=True, norm='l2')),
                     ('clf', svm.LinearSVC(C=90.01, class_weight=None, dual=True, fit_intercept=True,
     intercept_scaling=1, loss='squared_hinge', max_iter=10000,
     multi_class='ovr', penalty='l2', random_state=0, tol=1e-04, verbose=0))])

pr.fit(x_train, y_train)
predictions = pr.predict(x_test)
f1Score=metrics.f1_score(y_test,predictions)
print(f1Score)
# Out:
# 0.9604049900560476

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
pr=Pipeline([('vect', CountVectorizer(ngram_range=(1, 2))),
                     ('tfidf', TfidfTransformer(use_idf=True, norm='l2')),
                     ('clf', LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True, 
                                                intercept_scaling=1, max_iter=100, 
                                                multi_class='warn', n_jobs=None, penalty='l2', 
                                                solver='warn', tol=0.0001, verbose=0, 
                                                warm_start=False))])
pr.fit(x_train, y_train)
predictions = pr.predict(x_test)
f1Score=metrics.f1_score(y_test,predictions)
print(f1Score)
# Out:
# d:\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9503365472075678

# %%
pr=Pipeline([('vect', CountVectorizer(ngram_range=(1, 2))),
                     ('tfidf', TfidfTransformer(use_idf=True, norm='l2')),
                     ('clf', MultinomialNB(alpha=0.02))])
pr.fit(x_train, y_train)
predictions = pr.predict(x_test)
f1Score=metrics.f1_score(y_test,predictions)
print(f1Score)
# Out:
# 0.9703465523401215

# %%
#Now working with Real challenge Data
train_x=train_clean['tweet']
valid_x=test_clean['tweet']
train_y=train_clean['label']

pr=Pipeline([('vect', CountVectorizer(ngram_range=(1, 2))),
                     ('tfidf', TfidfTransformer(use_idf=True, norm='l2')),
                     ('clf', MultinomialNB(alpha=0.02))])
pr.fit(x_train, y_train)
predictions = pr.predict(valid_x)
d={'id':test['id'],'label':predictions}
df=pd.DataFrame(data=d)
df.to_csv("test_predictions_MultiNomialNB_Markov.csv", index=False)

# %%
'''#Now working with Real challenge Data
train_x=train_clean['tweet']
valid_x=test_clean['tweet']
train_y=train_clean['label']

pr=Pipeline([('vect', CountVectorizer(ngram_range=(1, 2))),
                     ('tfidf', TfidfTransformer(use_idf=True, norm='l2')),
                     ('clf', svm.LinearSVC(C=90.01, class_weight=None, dual=True, fit_intercept=True,
     intercept_scaling=1, loss='squared_hinge', max_iter=10000,
     multi_class='ovr', penalty='l2', random_state=0, tol=1e-04, verbose=0))])
#Scored 0.733834586466165
pr.fit(x_train, y_train)
predictions = pr.predict(valid_x)
d={'id':test['id'],'Tweet':valid_x,'label':predictions}
df=pd.DataFrame(data=d)
df.to_csv("test_predictions_LinearSVC_Markov.csv")'''
